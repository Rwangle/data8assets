# %% [markdown]
# # Homework 4: Functions and Histograms
#
# Please complete this notebook by filling in the cells provided. When you’re done, follow the instructions in [this short explainer video](https://www.youtube.com/watch?v=gMt_Rq43y_4&ab_channel=FahadKamran) to submit your homework.
#
# If you cannot submit online, come to office hours for assistance. The office hours
# schedule appears on [data8.org/fa16/weekly.html](http://data8.org/fa16/weekly.html).
#
# This assignment is due Thursday, September 22 at 5PM. You will receive an early submission bonus point if you turn it in by Wednesday, September 21 at 5PM. Directly sharing answers is not okay, but discussing problems with course staff or with other students is encouraged.
#
# Reading:
# - Textbook chapters [6](http://www.inferentialthinking.com/chapters/06/visualization.html) and [7](http://www.inferentialthinking.com/chapters/07/functions-and-tables.html)

# %% [markdown]
# Run the cell below to prepare the notebook and the tests. **Passing the automatic tests does not guarantee full credit on any question.** The tests are provided to help catch some common errors, but it is *your* responsibility to answer the questions correctly.

# %%
# Run this cell to set up the notebook, but please don't change it.
import numpy as np
from datascience import *

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)

from client.api.assignment import load_assignment
tests = load_assignment('hw04.ok')
# Out:
# =====================================================================
# Assignment: Homework 4: Functions and Histograms
# OK, version v1.14.15
# =====================================================================

# %% [markdown]
# ## 1. Predicting Temperatures

# %% [markdown]
# In this exercise, we will try to predict the weather in California using the prediction method  discussed in [section 7.1 of the textbook](https://www.inferentialthinking.com/chapters/07/1/applying-a-function-to-a-column.html).  Much of the code is provided for you; you will be asked to understand and run the code and interpret the results.
#
# The US National Oceanic and Atmospheric Administration (NOAA) operates thousands of climate observation stations (mostly in the US) that collect information about local climate.  Among other things, each station records the highest and lowest observed temperature each day.  These data, called "Quality Controlled Local Climatological Data," are publicly available [here](http://www.ncdc.noaa.gov/orders/qclcd/) and described [here](https://www.ncdc.noaa.gov/data-access/land-based-station-data/land-based-datasets/quality-controlled-local-climatological-data-qclcd).
#
# `temperatures.csv` contains an excerpt of that dataset.  Each row represents a temperature reading in Fahrenheit from one station on one day.  (The temperature is actually the highest temperature observed at that station on that day.)  All the readings are from 2015 and from California stations.

# %%
temperatures = Table.read_table("temperatures.csv")
temperatures
# Out:
# Temperature | Date | Latitude | Longitude | Station name
# 67          | 1013 | 40.9781  | -124.109  | Arcata/Eureka
# 63          | 811  | 38.3208  | -123.075  | Bodega
# 94          | 706  | 39.1019  | -121.568  | Marysville
# 59          | 1211 | 36.9358  | -121.789  | Watsonville
# 111         | 620  | 32.8342  | -115.579  | Imperial
# 88          | 821  | 33.9     | -117.25   | Riverside
# 68          | 606  | 33.938   | -118.389  | Los Angeles
# 66          | 205  | 37.2847  | -120.513  | Merced
# 89          | 902  | 39.49    | -121.618  | Oroville
# 105         | 728  | 34.8536  | -116.786  | Daggett
# ... (990 rows omitted)

# %% [markdown]
# Here is a scatter plot:

# %%
temperatures.scatter("Date", "Temperature")

# %% [markdown]
# Each entry in the column "Date" is a number in MMDD format, meaning that the last two digits denote the day of the month, and the first 1 or 2 digits denote the month.
#
# **Question 1.** Why do the data form vertical bands with gaps?

# %% [markdown]
# the dates are exressed as whole numbers whose last two digits are the number of days in a month (ie up to 31.), the numbers past 31 to 99 have no meaning for dates and are not included. Need to transfer the date expression into dates that can be expressed in a contiguous line.

# %% [markdown]
# Let us solve that problem.  We will convert each date to the number of days since the start of the year.

# %%
def get_month(date):
    """The month in the year for a given date.
    
    >>> get_month(315) 
    3
    """
    return int(date / 100)

def get_day_in_month(date):
    """The day in the month for a given date.
    
    >>> get_day_in_month(315)
    15
    """
    return date % 100

DAYS_IN_MONTHS = Table().with_columns(
    "Month", np.arange(1, 12+1),
    "Days in Month", make_array(31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31))

# A table with one row for each month.  For each month, we have
# the number of the month (e.g. 3 for March), the number of
# days in that month in 2015 (e.g. 31 for March), and the
# number of days in the year before the first day of that month
# (e.g. 0 for January or 59 for March).
DAYS_SINCE_YEAR_START = DAYS_IN_MONTHS.with_column(
    "Days since start of year", np.cumsum(DAYS_IN_MONTHS.column("Days in Month")) - DAYS_IN_MONTHS.column("Days in Month"))

def days_since_year_start(month):
    """The number of days in the year before this month starts.
    
    month should be the number of a month, like 3 for March.
    
    >>> days_since_year_start(3)
    59
    """
    return DAYS_SINCE_YEAR_START.where("Month", are.equal_to(month))\
                                .column("Days since start of year")\
                                .item(0)

# First, extract the month and day for each reading.
with_month_and_day = temperatures.with_columns(
    "Month", temperatures.apply(get_month, "Date"),
    "Day in month", temperatures.apply(get_day_in_month, "Date"))
# Compute the days-since-year-start for each month and day.
fixed_dates = with_month_and_day.apply(days_since_year_start, "Month") + with_month_and_day.column("Day in month")
# Add those to the table.
with_dates_fixed = with_month_and_day.with_column("Days since start of year", fixed_dates).drop("Month", "Day in month")
with_dates_fixed
# Out:
# Temperature | Date | Latitude | Longitude | Station name  | Days since start of year
# 67          | 1013 | 40.9781  | -124.109  | Arcata/Eureka | 286
# 63          | 811  | 38.3208  | -123.075  | Bodega        | 223
# 94          | 706  | 39.1019  | -121.568  | Marysville    | 187
# 59          | 1211 | 36.9358  | -121.789  | Watsonville   | 345
# 111         | 620  | 32.8342  | -115.579  | Imperial      | 171
# 88          | 821  | 33.9     | -117.25   | Riverside     | 233
# 68          | 606  | 33.938   | -118.389  | Los Angeles   | 157
# 66          | 205  | 37.2847  | -120.513  | Merced        | 36
# 89          | 902  | 39.49    | -121.618  | Oroville      | 245
# 105         | 728  | 34.8536  | -116.786  | Daggett       | 209
# ... (990 rows omitted)

# %% [markdown]
# **Question 2.** In the cell above, what is the value of this expression?
#
#     np.cumsum(DAYS_IN_MONTHS.column("Days in Month")) - DAYS_IN_MONTHS.column("Days in Month")
#
# Describe its type and what its value (or the values in it, if it's an array or table) means.
#
# *Hint:* You can write `np.cumsum?` to get documentation for the function `cumsum`.

# %%
# You can write code in this cell to help you answer this
# question, if you want to.
np.cumsum(DAYS_IN_MONTHS.column("Days in Month")) - DAYS_IN_MONTHS.column("Days in Month")
# Out:
# array([  0,  31,  59,  90, 120, 151, 181, 212, 243, 273, 304, 334])

# %% [markdown]
# The value of the expression is an array of cumulative days in a year at the beginning of each month. (the second, subtracted portion "- DAYS_IN_MONTHS.column("Days in Month") " removes the days in the current month, and changes it from the cum sum at the end of each month into the cumulative sum at the start of each month.

# %% [markdown]
# Now we can make a better scatter plot.

# %%
with_dates_fixed.scatter("Days since start of year", "Temperature")
with_dates_fixed
# Out:
# Temperature | Date | Latitude | Longitude | Station name  | Days since start of year
# 67          | 1013 | 40.9781  | -124.109  | Arcata/Eureka | 286
# 63          | 811  | 38.3208  | -123.075  | Bodega        | 223
# 94          | 706  | 39.1019  | -121.568  | Marysville    | 187
# 59          | 1211 | 36.9358  | -121.789  | Watsonville   | 345
# 111         | 620  | 32.8342  | -115.579  | Imperial      | 171
# 88          | 821  | 33.9     | -117.25   | Riverside     | 233
# 68          | 606  | 33.938   | -118.389  | Los Angeles   | 157
# 66          | 205  | 37.2847  | -120.513  | Merced        | 36
# 89          | 902  | 39.49    | -121.618  | Oroville      | 245
# 105         | 728  | 34.8536  | -116.786  | Daggett       | 209
# ... (990 rows omitted)

# %%
print("smaller set for myself")
with_dates_fixed.where("Station name","Van Nuys").scatter("Days since start of year","Temperature")
# Out:
# smaller set for myself

# %% [markdown]
# Let's do some prediction.  For any reading on any day, we will predict its value using all the readings from the week before and after that day.  A reasonable prediction is that the reading will be the average of all those readings.  We will package our code in a function.

# %%
PREDICTION_RADIUS = 7

def predict_temperature(day):
    """A prediction of the temperature (in Fahrenheit) on a given day at some station.
    """
    nearby_readings = with_dates_fixed.where("Days since start of year", are.between_or_equal_to(day - PREDICTION_RADIUS, day + PREDICTION_RADIUS))
    return np.average(nearby_readings.column("Temperature"))

# %% [markdown]
# **Question 3.** Suppose you're planning a trip to Yosemite for Thanksgiving break this year, and you'd like to predict the temperature on November 26 (the Saturday after Thanksgiving). Use `predict_temperature` to compute a prediction for a temperature reading on that day.
#
# *Hint:* In addition to `predict_temperature`, another function we wrote earlier will be helpful.

# %%
#days since year start function gives the days in the year up till the start of the month from the array in question 2, when given a month number. This can be added to the days in the month (calc by get_days_in_month) to get days since year start
#get month using get_month using date in the in the form 1126 as 11/26
date=1126 
thanksgiving_prediction = predict_temperature(days_since_year_start(get_month(date))+get_day_in_month(date))
thanksgiving_prediction
# Out:
# 64.31914893617021

# %%
_ = tests.grade('q1_3')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# Below we have computed a predicted temperature for each reading in the table and plotted both.  (It may take a **minute or two** to run the cell.)

# %%
with_predictions = with_dates_fixed.with_column(
    "Predicted temperature",
    with_dates_fixed.apply(predict_temperature, "Days since start of year"))
with_predictions.select("Days since start of year", "Temperature", "Predicted temperature")\
                .scatter("Days since start of year")

# %% [markdown]
# **Question 4.** How many times was the first line of the body of the function `predict_temperature` (the one that starts with `nearby_readings = ...`) executed when you ran the cell above?

# %% [markdown]
# if apply ran predict_temp for each entry of the column "days since start of year" it should have happened 1000 times?

# %% [markdown]
# **Question 5.** The scatter plot is called a *graph of averages*.  In the [example in the textbook](https://www.inferentialthinking.com/chapters/07/1/applying-a-function-to-a-column.html#Example:-Prediction), the graph of averages roughly followed a straight line.  Is that true for this one?  Using your knowledge about the weather, explain why or why not.

# %% [markdown]
# yes it is true, and the line roughly predicts the rise and decrease in temp as a year progresses through seasons. The last 140 or so days (last 5 months) of the year are the coldest.

# %% [markdown]
# **Question 6.** According to the [Wikipedia article](https://en.wikipedia.org/wiki/Climate_of_California) on California's climate, "[t]he climate of California varies widely, from hot desert to subarctic."  Suppose we limited our data to weather stations in a smaller area whose climate varied less from place to place (for example, the state of Vermont, or the San Francisco Bay Area).  If we made the same graph for that dataset, in what ways would you expect it to look different?

# %% [markdown]
# The smaller the area, the less variation one might expect day to day, so the line would be smoother. possibily fewer stations and feweer data points in general though, so that might make it more erratic instead. the trends would better match the specific locality though.

# %% [markdown]
# ## 2. Reading Documents

# %% [markdown]
# Often, we have to work with data that aren't in CSV format, but instead come in some less nice form.  In this exercise, we'll look at the text of some Reuters news reports from 1987.  Our dataset doesn't include *all* the news reports from that year, but it includes 1,000 of them.  Reuters doesn't say how the articles were selected.
#
# We've put the text of all the articles in a file called `reuters.txt`.  The cell below loads that file into a single big string and prints a few thousand characters, which is just enough to see one full article and the start of the next.  (Don't try to print the whole thing, because it's very long.)

# %%
# Just run this cell to load the dataset as one big string of text.
with open('reuters.txt', 'r') as file:
    big_reuters_string = file.read()

print("{:.5000}\n[...]".format(big_reuters_string))
# Out:
# <reuters cgisplit="PUBLISHED-TESTSET" lewissplit="NOT-USED" newid="12603" oldid="21460" topics="YES">
# <date> 2-APR-1987 11:11:23.62</date>
# <topics><d>livestock</d><d>carcass</d><d>trade</d></topics>
# <places><d>usa</d><d>japan</d></places>
# <people><d>lyng</d></people>
# <orgs></orgs>
# <exchanges></exchanges>
# <companies></companies>
# <unknown>
# C G L
# f1408reute
# u f BC-/LYNG-SETS-TOUGH-U.S.   04-02 0141</unknown>
# <text>
# <title>LYNG SETS TOUGH U.S. STANCE WITH JAPAN ON BEEF</title>
# <dateline>    WASHINGTON, April 2 - </dateline>U.S. Agriculture Secretary Richard
# Lyng warned Japan that the failure to remove a longstanding
# import quota on Japanese beef might spark a protectionist
# response in the United States.
#     "Given the protectionist mood in the Congress and the
# country, if I were a leader in Japan I would certainly be very
# concerned...and the failure to remove it (the beef quota) might
# be very serious," Lyng told a group of U.S cattlemen.
#     Lyng said he and Trade Representative Clayton Yeutter,
# during a visit to Japan later this month, will demand "total
# elimination" of the beef import quota by April 1988.
#     The current dispute with Japan over semiconductor may
# strengthen the U.S. stance in farm trade negotiations, Lyng
# said, because Japan does not want a trade war with the U.S.
#     Lyng dismissed recent statements in Tokyo that Japan might
# retaliate against U.S. products as a result of the
# semiconductor dispute.
#     "They (Japan) aren't going to pick a fight with us," Lyng
# said, adding that with its huge bilateral trade surplus Japan
# has more to lose in a trade war than the United States.
#     Lyng told the U.S. cattlemen that the quota on Japanese
# beef imports does not allow consumers there an adequate choice
# in food purchases.
#     He said in addition to beef, the U.S. will press for
# eliminiation of import barriers on Japan's citrus and rice as
# well.
#     Lyng noted that Japan is the largest buyer of U.S. farm
# products, principally grains and soybeans.
#  Reuter
# </text>
# </reuters>***ARTICLE***<reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid="19096" oldid="6932" topics="NO">
# <date>19-JUN-1987 08:19:25.45</date>
# <topics></topics>
# <places><d>usa</d></places>
# <people></people>
# <orgs></orgs>
# <exchanges></exchanges>
# <companies></companies>
# <unknown>
# F
# f0606reute
# u f BC-DE-LAURENTIIS-COMPANI   06-19 0050</unknown>
# <text>
# <title>DE LAURENTIIS COMPANIES SEE LOSS ON FILM</title>
# <dateline>    LOS ANGELES, June 19 - </dateline>De Laurentiis Film Partners LP <DFP>
# and De Laurentiis Entertainment Group Inc <DEG> said they will
# take charges of five mln and 6,500,000 dlrs repsectively on
# their film "Million Dollar Mystery" due to disappointing box
# office results.
#  Reuter
# </text>
# </reuters>***ARTICLE***<reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newid="3541" oldid="8454" topics="YES">
# <date>11-MAR-1987 08:16:54.73</date>
# <topics><d>bop</d></topics>
# <places><d>portugal</d></places>
# <people></people>
# <orgs></orgs>
# <exchanges></exchanges>
# <companies></companies>
# <unknown>
# RM
# f0775reute
# u f BC-PORTUGUESE-TRADE-DEFI   03-11 0115</unknown>
# <text>
# <title>PORTUGUESE TRADE DEFICIT NARROWS IN 1986</title>
# <dateline>    LISBON, March 11 - </dateline>Portugal's trade deficit narrowed in
# 1986 to 336.5 billion escudos from 354.8 billion in 1985,
# according to provisional National Statistics Institute figures.
#     Imports totalled 1,412.6 billion escudos and exports
# 1,076.1 billion compared with 1,326.5 billion and 971.7 billion
# in 1985.
#     Expressed in terms of dollars, imports rose 21.2 pct and
# exports 26.1 pct and the trade deficit increased by 7.8 pct.
#     In its first year as a member of the European Community,
# Portugal recorded a deficit of 98.1 billion escudos in its
# trade with the other Community states compared with a deficit
# of 2.4 billion escudos in 1985.
#     Imports from the EC in 1986 totalled 830.2 billion escudos,
# while exports to the Community were 732.1 billion, compared
# with 609.5 billion and 607.1 billion the previous year.
#     Portugal's deficit with Spain was 83.2 billion escudos
# against 57.7 billion in 1985, with Italy it was 70.4 billion
# against 30.3 billion, and with West Germany 40.5 billion
# against 19.1 billion.
#  REUTER
# </text>
# </reuters>***ARTICLE***<reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newid="10003" oldid="15524" topics="NO">
# <date>26-MAR-1987 12:15:35.31</date>
# <topics></topics>
# <places><d>usa</d><d>uk</d><d>switzerland</d><d>belgium</d><d>luxembourg</d></places>
# <people></people>
# <orgs></orgs>
# <exchanges></exchanges>
# <companies></companies>
# <unknown>
# F
# f1735reute
# r f BC-BIOGEN-<BGNF>-GETS-PA   03-26 0103</unknown>
# <text>
# <title>BIOGEN <BGNF> GETS PATENT FROM EUROPEAN OFFICE</title>
# <dateline>    CAMBRIDGE, Mass., March 26 - </dateline>Biogen Inc said the European
# Patent Office granted it a patent covering certain proteins
# used to produce a hepatitis B vaccine through genetic
# engineering techniques.
#     Robert Gottlieb, Biogen spokesman, said the company has
# licensed the vacci
# [...]

# %% [markdown]
# There's a bunch of weird text for each article.  Each article is separated from its neighbors by the string `"***ARTICLE***"`.
#
# **Question 1.** Use the String method `split` to make an array of the text of all the articles.  That is, each entry of this array should be the text of one article.  Put that array in a new table called `reuters` as a column with the name "Raw text".
#
# *Hint:* When you split the articles correctly, you should see that each article starts with `"<reuters..."` and ends with `"...</reuters>"`.  There should be 1,000 articles.
#
# *Hint 2:* As an example, `"steamcleaner".split("ea")` is the same as `make_array('st', 'mcl', 'ner')`.  So you want to split the big string that contains all the data, splitting with the text `"***ARTICLE***"`.

# %%
reuters = Table().with_column(
        "Raw text", big_reuters_string.split("***ARTICLE***")
    )
reuters
# Out:
# Raw text
# <reuters cgisplit="PUBLISHED-TESTSET" lewissplit="NOT-US ...
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ...
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ...
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ...
# <reuters cgisplit="PUBLISHED-TESTSET" lewissplit="NOT-US ...
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ...
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ...
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ...
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ...
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ...
# ... (990 rows omitted)

# %%
_ = tests.grade('q2_1')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# Each article has a line containing its title that looks something like this:
#
#     <title>LYNG SETS TOUGH U.S. STANCE WITH JAPAN ON BEEF</title>
#
# You could find that yourself for a few of the articles, but it would be very tedious to do it for all 1,000 articles.  So we'll write code to do it instead.
#
# **Question 2.** Below, we've written a function called `get_text_in_markers` that will help you find the title text for an article.  Use it to write a function called `get_title`, which is also documented below.

# %%
# This function is provided for you to use.  Read at least
# its documentation (the stuff at the beginning in red).
# You can also type in get_text_in_markers? somewhere and
# run it to see the documentation in a slightly nicer form.
# We haven't used any tools you haven't seen yet, so it
# wouldn't hurt to read the code itself, too.
def get_text_in_markers(text, marker):
    """Finds the part of a piece of text that's between specified markers.
    
    Parameters
    ----------
    text : str
        The text in which you want to find something.
    marker : str
        The name of the marker that delimits the part of the
        text you want to grab.  In the text itself, this string
        will be surrounded by "<>" or "</>", but don't include
        those angle brackets in this argument.
    
    Returns
    -------
    str
        The parts of the text that are inside the markers.
    
    Examples
    --------
    >>> get_text_in_markers("stuff <interesting>yay exciting</interesting> more stuff", "interesting")
    'yay exciting'
    """
    start_marker = "<{}>".format(marker)
    end_marker = "</{}>".format(marker)
    split_before = np.array(text.split(start_marker))
    marker_text_and_after = split_before.item(1)
    split_on_end_marker = np.array(marker_text_and_after.split(end_marker))
    return split_on_end_marker.item(0)

# Fill in this function.
def get_title(article_text):
    return get_text_in_markers(article_text, "title")
    """Takes the text of an article and returns its title."""
    

# When you're done, this should produce 'LYNG SETS TOUGH U.S. STANCE WITH JAPAN ON BEEF'.
get_title(reuters.column("Raw text").item(0))
# Out:
# 'LYNG SETS TOUGH U.S. STANCE WITH JAPAN ON BEEF'

# %%
_ = tests.grade('q2_2')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# **Question 3.** Now use your function to find the title of every article in `reuters`.  Create a new table called `with_titles` that's a copy of `reuters` with an extra column named "Title" that contains these titles.
#
# *Note:* This might take a few seconds to run.

# %%
reuters.apply(get_title, "Raw text")
# Out:
# array(['LYNG SETS TOUGH U.S. STANCE WITH JAPAN ON BEEF',
#        'DE LAURENTIIS COMPANIES SEE LOSS ON FILM',
#        'PORTUGUESE TRADE DEFICIT NARROWS IN 1986',
#        'BIOGEN <BGNF> GETS PATENT FROM EUROPEAN OFFICE',
#        'DEFENSE CONTRACTOR BOOSTS BIRD <BIRD> STAKE',
#        "MOODY'S MAY DOWNGRADE RESORTS INTERNATIONAL <RT>",
#        'RECORD N.Z. FUTURES VOLUMES TRADED IN FEBRUARY',
#        'SWISS SIGHT DEPOSITS RISE 743.7 MLN FRANCS',
#        'IRAN SAYS IT INTENDS NO THREAT TO GULF SHIPPING',
#        'BUSINESSLAND <BUSL> COMPLETES OFFERING',
#        'JANNOCK LTD <JN.TO> 3RD QTR NET',
#        'PRESIDENTIAL <PAIR.O> APRIL LOAD FACTOR DROPS',
#        'HOSPITAL CORP <HCA> BOARD AGAINST BUYOUT BID',
#        'BROUGHER INSURANCE GROUP INC<BIGI> 4TH QTR LOSS',
#        'NEW U.K. POLL SAYS TORIES HAVE SIX-POINT LEAD',
#        'PRIMARY GILTS DEALERS NEED NOT BUY AT AUCTIONS',
#        'CONTI SHARES OPEN HIGHER ON GOOD NEW TYRE REVIEWS',
#        'BUNDESBANK BOUGHT DOLLARS FOR YEN IN OPEN MARKET',
#        'WESTINGHOUSE <WX> GETS 114 MLN DLRS IN CONTRACTS',
#        'AUSTRALIAN SUGAR AREAS SAID RECEIVING SOME RAIN',
#        '<ASTA GROUP INC> UNIT IN LOAN PURCHASE',
#        'SYMS CORP <SYM> 4TH QTR',
#        'SEC REMOVES OBSTACLE TO FOREIGN FUTURES TRADING',
#        'PETRO-CANADA TO DRILL TWO TERRA NOVA TEST WELLS',
#        'INTEREST RATE DIFFERENTIALS TOO SMALL, BANKER SAYS',
#        'AMOCO <AN> CANADA OFFER TO TOP ONE BILLION DLRS',
#        'DUTCH PRODUCER PRICES RISE 0.3 IN JANUARY',
#        'AEL INDUSTRIES INC <AELNA.O> FIRST QTR NET',
#        'FIDATA <FID> ANNOUNCES PRELIMINARY ESM SETTLEMENT',
#        'AUSTRALIAN OPPOSITION LEADER SACKS PREDECESSOR',
#        'NORTH CAROLINA FEDERAL <NCFS> RAISES PRIME RATE',
#        'RENISON GOLDFIELDS EXTENDS LYELL COPPER MINE LIFE',
#        'AFFILIATED PUBLICATIONS INC <AFP> SETS PAYOUT',
#        'TOSHIBA HOPES EXPORTS TO U.S. NOT HURT',
#        'HOG AND CATTLE SLAUGHTER GUESSTIMATES',
#        'MONSANTO TO BUY RHONE-POULENC POLYPHENYL BUSINESS',
#        'ADOBE SYSTEMS INC <ADBE> 1ST QTR FEB 28 NET',
#        'IRANIAN OIL MINISTER ARRIVES IN ALGERIA',
#        'IRVING BANK CORP 1ST QTR SHR 1.51 DLRS VS 1.62 DLRs\n',
#        'REAGAN URGES FULFILLMENT OF EXCHANGE ACCORDS',
#        'DEUTSCHE BABCOCK RIGHTS ISSUE PRICED AT 165 MARKS',
#        'UNIFORCE TEMPORARY PERSONNEL INC <UNFR> 4TH QTR',
#        'IC INDUSTRIES <ICX> NAMES KARL BAYS AS CHAIRMAN',
#        'BET TO APPLY FOR LISTINGS IN NEW YORK, TORONTO',
#        'UNITED ARTISTS <UACI.O> SUSPENDS MERGER TALKS',
#        "ITALY'S AGIP PETROLI BUYS STAKE IN U.S. COMPANY",
#        'REAGAN AND BAKER BEGIN TASK OF REBUILDING',
#        'BANKAMERICA <BAC> SAYS IT WILL MAKE DEBT OFFER',
#        'RAYTHEON <RTN> NET RISES ON OPERATIONS',
#        "FED'S JOHNSON SAYS LOWER DOLLAR WOULD EXACERBATE MARKET CONDITIONS\n",
#        "MOODY'S DOWNGRADES BAKER INTERNATIONAL AND UPGRADES HUGHES TOOL\n",
#        'WARBURG PINCUS STARTS SYMBION <SYMB> BID',
#        'BRITAIN TO MINT NEW "BRITANNIA" GOLD COIN',
#        'SHV WITHDRAWS IC GAS OFFER',
#        'BANGLADESH TENDERS FOR TWO MLN BARRELS PETROLEUM',
#        'INVESTOR BOOSTS FIRST WESTERN <FWES> STAKE',
#        'TAIWAN BUYS 462,000 TONNES OF U.S. MAIZE',
#        'INITIALS PLUS <IINC> SEES SHARP SALES INCREASE',
#        'LATIN AMERICAN, SPANISH BANK GOVERNORS TO MEET',
#        'BRAZIL DEBT SEEN PARTNER TO HARD SELL TACTICS',
#        'CHRYSLER <C> IN DEAL TO BUY AMC <AMO>',
#        'PRESIDENT REAGAN VOWS TO VETO ANY TAX INCREASE',
#        'NATIONAL WESTMINSTER BANK CUTS BASE RATE',
#        'AVNET <AVT> FILES CONVERTIBLE DEBT OFFERING',
#        "U.S. FDA APPROVES BURROUGHS WELLCOME'S AZT TO TREAT  CERTAIN AIDS PATIENTS\n",
#        'U.S., JAPAN CHIP TALKS TO START NEXT WEEK',
#        'ANGELL CARE MASTER LP <ACR> RAISES QUARTERLY',
#        'AMERIHEALTH INC <AHTH> 4TH QTR LOSS',
#        'STANLEY INTERIORS <STHF> SAYS RESULTS REDUCED',
#        'DUTCH FINANCE MINISTER APPLAUDS NEW FED CHIEF',
#        'INTERNATIONAL PROTEINS <PRO> REPLACES CREDIT',
#        'TEXAS AIR <TEX> UNIT TO ADD MEXICO FLIGHTS',
#        '(GEOFFRION LECLERC INC) SIX MTHS NET',
#        'A.T. BROD NAMES NEW PRESIDENT',
#        'I.U. INTERNATIONAL <IU> TO SELL INSURANCE UNITS',
#        'COMPUTER IDENTICS <CIDN> NAMES CHIEF EXECUTIVE',
#        'CANADA CURRENT ACCOUNT DEFICIT UP IN QUARTER',
#        'DOW STOCK MARKET DROPS OVER 100 POINTS\n',
#        'USDA SEEKING COMMENTS ON 1988 FARM PROGRAMS',
#        'CHEMLAWN <CHEM> RISES ON HOPES FOR HIGHER BIDS',
#        'DIAMOND SHAMROCK RAISED CRUDE BY 50 CTS/BBL TODAY. WTI UP TO 17.50 DLRS.\n',
#        'EC COMMISSION DETAILS SUGAR TENDER',
#        'DETROIT EDISON <DTE> SELLS BONDS IN TWO TRANCHES',
#        'FINNISH EXPORT CREDIT ISSUES YEN BONDS',
#        'CONTEL <CTC> UNIT SALES SEEN BY ANALYSTS',
#        'IDEAL SCHOOL SUPPLY CORP <IDEL> 4TH QTR NET',
#        'CARTER HAWLEY HALE <CHH> FEBRUARY SALES RISE',
#        'ANCHOR GLASS CONTAINER CORP <ANC> 3RD QTR NET',
#        'FLEET FINANCIAL GROUP 1ST QTR SHR 73 CTS VS 60 CTS \n',
#        'AUSTRALIAN GOVERNMENT MUST CUT SPENDING, ANZ SAYS',
#        "USDA'S AMSTUTZ CONFIDENT OF EC OILS TAX DEFEAT",
#        '<ITT CANADA LTD> YEAR NET',
#        'MCCORMICK CAPITAL <MKOR> 1986 YEAR NET',
#        "MOODY'S DOWNGRADES 1.8 BILLION DLRS OF DEERE, RELATED DEBT\n",
#        'MORTGAGE GROWTH INVESTORS <MTG> 1ST QTR FEB 28',
#        'BLOCKER ENERGY CORP <BLK> YEAR NET',
#        'U.S. BANKS LIKELY TO LIFT PRIME RATES AGAIN SOON',
#        'ITALY CONSUMER PRICES RISE 0.4 PCT IN FEBRUARY',
#        'NECO <NPT> POSTPONES ANNUAL MEETING',
#        'HITACHI UNIT MAY WITHDRAW FROM U.S. MARKET',
#        'PETRIE STORES CORP <PST> SETS QUARTERLY',
#        'CUBAN SUGAR OUTPUT SEEN AT 7.5 MLN TONNES',
#        'WAITING PERIOD ENDS ON WASTE MANAGEMENT<WMX> BID',
#        'IMPERIAL OIL RAISES CRUDE OIL POSTINGS 32 CANADIAN\nCTS/BBL, LIGHT SWEET NOW 25.60\n\n',
#        'SHULTZ WELCOMES TOKYO ECONOMIC PACKAGE',
#        'ITT CORP TO REDEEM THREE SERIES OF PREFERRED STOCK\n',
#        'DAMON <DMN> UNIT TO MANAGE CLINICAL LAB',
#        'STRIKES AGAINST WAGE FREEZE SPREAD IN YUGOSLAVIA',
#        '<NEWSCOPE RESOURCES LTD> YEAR LOSS',
#        'BALLY <BLY> SHIFTS MANAGEMENT AT SUBSIDIARY',
#        'PACIFIC INTERNATIONAL <PISC.O> TO OFFER DEBT',
#        'SEACOAST BANKING CORP OF FLORIDA <SBCF.O> 3RD',
#        'OKC <OKC> SAYS APPEALS COURT UPHOLDS RULING',
#        'UNION CARBIDE <UK> SELLS NOTES YIELDING 9.90 PCT',
#        'DOE RESOLVES ISSUES WITH ROYAL DUTCH <RD> UNIT',
#        'POLAROID CORP 3RD QTR SHR 39 CTS VS 39 CTS\n',
#        'U.S. CREDIT MARKET OUTLOOK - BUDGET DEFICIT',
#        'BIDS AWARDED FOR ELK HILLS CRUDE OIL',
#        'DANISH SUGAR BEET PLANTING BEHIND SCHEDULE',
#        'CONVERGENT TECHNOLOGIES <CVGT> TO BUY OAKLEAF',
#        'MOORE MCCORMACK <MMC> TO SELL GLOBE UNIT',
#        'VESSEL LOST IN PACIFIC WAS CARRYING LEAD',
#        'IFR SYSTEMS INC <IFRS.O> 1ST QTR SEPT 30 NET',
#        'BONN SEEN REJECTING NEW GROWTH MEASURES AT SUMMIT',
#        'MAJESTIC ELECTRONICS PLANS ISSUER BID',
#        'INGERSOLL-RAND CO <IR> 3RD QTR NET',
#        'SUGAR QUOTA IMPORTS DETAILED -- USDA',
#        'STRIKING BRAZIL SEAMEN THREATEN MASS RESIGNATION',
#        '<BIO-VASCULAR INC> 1ST QTR JAN 31 LOSS',
#        'PS GROUP INC <PSG> QTLY DIVIDEND',
#        'ECUADOR CRUDE OIL EXPORTS STOPPED FOR FIVE MONTHS',
#        'LOPAT <LPAT> NAMES WEST COAST DISTRIBUTOR',
#        'PROVIDENCE ENERGY CORP <PVY> REGULAR DIVIDEND',
#        'VENEZUELA-ECUADOR OIL LOAN UNDER DISCUSSION',
#        'JAMES RIVER CORP <JR> SETS REGULAR PAYOUT',
#        "TREASURY'S BAKER SAYS DEBTOR NATIONS NEED TIMELY DISBURSEMENTS\n",
#        'JAPAN UNDERSTANDS U.S. ATTACK ON IRAN OIL PLATFORM',
#        'TRINOVA CORP 3RD QTR SHR 52 CTS VS 43 CTS\n',
#        'LATIN, CARIBBEAN NATIONS OPPOSE TRADE BILLS',
#        'STONE <STO> FILES FOR SECONDARY OFFERING',
#        'AMSTERDAM LAUNCHES 300 MLN GUILDER CP PROGRAM',
#        'BANKAMERICA <BACP> RAISES PRIME RATE TO 7.75 PCT',
#        'BOEING <BA> GETS ORDERS TOTALING 543 MLN DLRS',
#        'U.S. TELLS JAPAN TO DO MORE TO CUT TRADE SURPLUS',
#        '<BIFLYX> 2ND QTR DEC 31 NET',
#        'CCC ACCEPTS EXPORT BID FOR WHEAT FLOUR TO IRAQ',
#        'BNP PLANS 100 MLN H.K. DLR CD ISSUE',
#        'PESCH UNIT SEEKS BALANCE OF REPUBLIC HEALTH',
#        'BAXTER <BAX> STARTS CLINICAL TRIALS ON DRUG',
#        'EQUIMARK <EQK> PARTNERS TO BE DISSOLVED',
#        'WILLAMETTE INDUSTRIES <WMTT> 4TH QTR NET',
#        'CARLTON BUYS STAKE IN CENTRAL INDEPENDENT TV',
#        'INDIA COOL TO LIMITED U.S. SUPERCOMPUTER OFFER',
#        'WORLD BANK PRESIDENT OPPOSES DEBT FORGIVENESS',
#        'MOBIL <MOB> HAS NORTH SEA NATURAL GAS FIND',
#        'EC AWARDS 123,000 TONNES BARLEY EXPORT  LICENCES AT 138.75 ECUS PER TONNE - TRADERS\n',
#        'KUWAIT SAYS OPEC 2.4 MLN BPD BELOW CEILING',
#        "WARNER COMMUNICATIONS <WCI> UPGRADED BY MOODY'S",
#        'U.K. GROWING IMPATIENT WITH JAPAN - THATCHER',
#        '<TRANSIT FINANCIAL HOLDINGS INC> 4TH QTR NET',
#        'FIRST BOSTON <FBC> SWISS AFFILIATE BOOSTS STAKE',
#        'HARPER <HPR> GETS BID FROM HARCOURT <HBJ>',
#        'Bank of Japan bought 200 to 300 mln dlrs this morning, dealers said.\n',
#        '<NSA INC> OFFERS TO REPURCHASE OWN SHARES',
#        'JAPAN ISOLATED, YEN RISES, WORLD FEELS CHEATED',
#        'PANAMA CANAL OFFICIAL CONFIRMS NO 1988 TOLL RISE',
#        'FERRO <FOE> SEES STRONG 2ND QTR, SIX MONTHS',
#        '<TOTAL RESEARCH CORP> FISCAL 1987 NET',
#        'AFFILIATED PUBLICATIONS INC <AFP> SETS DIVIDEND',
#        'SYRIA SEEKING WHITE SUGAR NEXT MONTH - TRADE',
#        'WHITE HOUSE SAYS SHULTZ TRIP MAY LEAD TO SUMMIT',
#        'SWISS WARY OF U.S.-BRITISH BANK SUPERVISION PACT',
#        'H.J. HEINZ CO <HNZ> 3RD QTR JAN 28 NET',
#        'CANADIAN PACIFIC (CP) CONFIRMS EARNINGS',
#        'THAI NATURAL RUBBER EXPORTS RISE IN 1986',
#        'EUROPEAN SUPERCHIP PRODUCTION COULD START IN 1988',
#        'SAND TECHNOLOGY SYSTEMS <SNDCF> 2ND QTR NET',
#        'VOLCKER SAYS MORE STIMULUS ABROAD NEEDED FOR ADJUSTMENTS IN TRADE BALANCES\n',
#        'RABBIT SOFTWARE <RABT> TO MAKE ACQUISITION',
#        'PUBCO CORP <PUBO> YEAR NET',
#        'BANK OF FRANCE LEAVES INTERVENTION RATE UNCHANGED',
#        'JAPANESE ECONOMIC PACKAGE SEEN AS MAJOR CHANGE',
#        'EC TO BOOST SPENDING ON JOB CREATION THIS YEAR',
#        "GM'S <GM> PONTIAC HAS INTEREST RATE INCENTIVES",
#        "PEOPLE'S SAVINGS BANK OF BROCKTON <PBKB.O>",
#        'PARIBAS SEEKING TO ADJUST ECUADOR OIL FACILITY',
#        'CENTURI INC <CENT> YEAR NET',
#        'ECUADOR MINISTER RAISES QUESTIONS ABOUT DEBT',
#        'N.Y. COCOA FUTURES QUIETLY LOWER EARLY',
#        'FINNS AND CANADIANS TO STUDY MTBE PRODUCTION PLANT',
#        'U.S. M-1 MONEY SUPPLY RISES 500 MLN DLRS IN MARCH 9 WEEK, FED SAYS\n',
#        'WEIS MARKETS <WMK> IN THREE FOR TWO STOCK SPLIT',
#        "GPU'S <GPU> THREE MILE ISLAND POWER REDUCED",
#        'ROYAL DUTCH/SHELL GROUP OF COS 4TH QTR NET',
#        'S. KOREA SETS RULES FOR OVER-THE-COUNTER MARKET',
#        'ROSTENKOWSKI SAYS REAGAN MUST RECONSIDER TAX RISE',
#        'U.K. MONEY MARKET GIVEN FURTHER 183 MLN STG HELP',
#        'INDIAN BANKER SAYS RATES CUT AFFECTS PROFITABILITY',
#        'GREASE MONKEY HOLDING CORP <GMHC> YEAR NOV 30',
#        'CHAMPION <CHA> IN 285 MLN DLR EXPANSION',
#        'COSTAIN TO CHANGE NAME TO COSCAN DEVELOPMENT',
#        'HANOVER INSURANCE <HINS> GET SPLIT APPROVAL',
#        'SUMITOMO BANK <SUMI> DECLARES STOCK DIVIDEND',
#        'BARTON VALVE <BART> HOLDERS APPROVE NAME CHANGE',
#        'ONE OF TWO SARA LEE <SLE> STRIKES SETTLED',
#        'VISHAY INTERTECHNOLOGY <VSH> CLARIFIES OFFER',
#        'ECUADOR SAYS WILL RESUME LIMITED OIL PRODUCTION',
#        'FLEET <FLT> COULD FACE CONNECTICUT DIVESTITURE',
#        'UNION PACIFIC <UNP> TO SELL PART OF REFINERY',
#        'FRENCH INDUSTRIAL PRODUCTION FALLS IN JANUARY',
#        'FIRE DAMAGES PAKISTAN SUGAR STOCK',
#        'UNOCAL <UCL> UNIT CUTS CRUDE OIL POSTED PRICES',
#        'SOY PLANTS MIGHT BE USED TO DRAW CADMIUM FROM SOIL',
#        'IRAN ANNOUNCES NEW OFFENSIVE IN GULF WAR',
#        'BALTEK <BTEK.O> BUYS ECUADORIAN PLANT',
#        'DIGIMED CORP 2ND QTR DEC 31 LOSS',
#        'SOVIET UNION, ISRAEL TO EXCHANGE DELEGATION VISITS',
#        'FED EXPECTED TO SET CUSTOMER REPURCHASES',
#        'MCI COMMUNICATIONS CALLS FOR IMMEDIATE DEREGULATION OF ATT    \n',
#        'TRADE SEES U.S. CORN EXPORTS UP, WHEAT/BEANS OFF',
#        'SPAIN TO SELL BARLEY TO SAUDI ARABIA',
#        'EC APPROVES 680 MLN STG U.K. AID TO ROVER GROUP',
#        'RAINIER <RBAN> COMPLETES ACQUISITION',
#        'CHEYENNE <CHYN.O> BUYS INTERESTS IN PROPERTIES',
#        'UNION NATIONAL <UNBC> SIGNS DEFINITIVE PACT',
#        "MOODY'S MAY CUT ECOLAB <ECL>, UP CHEMLAWN <CHEM>",
#        'ROCHESTER GAS <RGS> OFFERED PRD SHARES',
#        'REUTER CANADA BUSINESS HIGHLIGHTS',
#        'AUSTRALIA ATTACKS U.S. GATT FARM RULES EXEMPTION',
#        'GM LATE FEBRUARY CAR SALES OFF 8.6 PCT',
#        'GOLDEN TECH RESOURCES <GTS.V> UNIT NOTES SALES',
#        'TOSHIBA CORP <TSBA.T> YEAR ENDED MARCH 31',
#        'IMF, DEVELOPMENT BANKS, TO ASSIST ECUADOR',
#        'INTEGRATED <IGNG> FIELD TRIALS APPROVED',
#        'PHILADELPHIA HALTS MAJOR INDEX OPTION TRADE',
#        'FRENCH AGRICULTURAL BANK ISSUES 300 MLN FRANC BOND',
#        'U.K. JAN INDUSTRIAL OUTPUT RISES 0.4 PCT, MANUFACTURING DOWN 2.3 PCT - OFFICIAL\n',
#        'BELGIAN BOURSE TAX MOVE BLOCKED IN CABINET',
#        'GREAT WESTERN <GWF> TO REDEEM DEBENTURES',
#        'ECUADOR DEBT TO BE HONOURED AFTER QUAKE SURVIVAL',
#        'SIERRA SPRING WATER CO <WTR> 4TH QTR LOSS',
#        'UN CONFERENCE FORMALLY ADOPTS NEW RUBBER PACT',
#        'GULF STATES <GSU> SUBMITS FINANCING PLAN',
#        'ECUADOR TO ASK OPEC TO RAISE EXPORT QUOTA',
#        'CROSS AND TRECKER <CTCO> TO SELL UNIT',
#        'NEC CORP TARGETS HOME ELECTRONICS BUSINESS',
#        'DUTCH COCOA PROCESSORS UNHAPPY WITH ICCO BUFFER',
#        'PHILIPPINE CENTRAL BANKER FACES CORRUPTION CHARGES',
#        'VENEZUELA TO LEND ECUADOR 50,000 BPD OF CRUDE',
#        'THERMO PROCESS <TPSI> COMPLETES ACQUSITION',
#        'PEOPLES HERITAGE BANK <PHBK> 1ST QTR NET',
#        'EARLY MARCH OPEC OUTPUT SEEN WELL BELOW CEILING',
#        "JAPAN'S LDP URGES MORE IMPORTS OF 12 FARM ITEMS",
#        'BURLINGTON NORTHERN INC TO BUY BACK FIVE MLN SHARES OR SEVEN PCT OF COMMON\n',
#        'FEDERATED DEPARTMENT STORES INC <FDS> 4TH QTR',
#        'ESSEX CHEMICAL <ESX> TO SELL CONVERTIBLE DEBT',
#        'UST INC <UST> 3RD QTR NET',
#        'GOULD <GLD> INTRODUCES NEW MINI SUPERCOMPUTERS',
#        'WOOLWORTHS LTD REPORTS 9.27 MLN DLR NET PROFIT YR END FEB 1 VS 63.20 MLN\n',
#        'PARIBAS PLAN TO ADJUST ECUADOR LOAN TERMS OPPOSED',
#        'MINISTERS FEEL EC FORECASTS TOO PESSIMISTIC',
#        'MEDAR INC <MDXR> 4TH QTR DEC 31 LOSS',
#        'CORADIAN <CDIN.O> STAKE ACQUIRED BY SAGE',
#        'GAF <GAF> DEBT MAY BE DOWNGRADED BY S/P',
#        'U.S. ALUMINUM STOCKS HIGHER IN DECEMBER - ABMS',
#        'ASARCO <AR> COMPLETES SHARE OFFERING',
#        'PEP BOYS - MANNY, MOE AND JACK INC <PBY> 4TH QTR',
#        'WORLD BANK ISSUES AUSTRALIAN DLR ZERO COUPON BOND',
#        'ECUADOR INDUSTRY AND TRADE MINISTER RESIGNS',
#        'UAW SAYS IT BACK CHRYSLER <C>, AMC <AMO> MERGER',
#        'CBT SOYBEAN FUTURES CLOSE STRONG IN NEW CROP',
#        "HOUSE VOTES TO OVERRIDE PRESIDENT REAGAN'S VETO OF 88 BILLION DLR HIGHWAY FUNDING BILL\n",
#        'SENIOR ECONOMIST PREDICTS 30 PCT FALL IN DOLLAR',
#        'BENETTON SEES HIGHER PROFIT, SALES IN 1987',
#        'ECUADOR SEEKS 450 MLN DLRS IN EMERGENCY CREDIT',
#        'NIPPON STEEL INVESTS 8 MLN DLRS IN GTX CORP',
#        'ECUADOR POSTS 71.3 MLN DLR 8-MTH TRADE DEFICIT',
#        'ECUADOR SAYS SUSPENDS OIL EXPORTS DUE EARTHQUAKE',
#        'INTERNATIONAL TELECHARGE IN PUBLIC OFFERING',
#        'INTEL, MATRA-HARRIS DISSOLVE CIMATEL PARTNERSHIP',
#        'UK DISCUSSES INSIDER TRADING WITH CHANNEL ISLANDS',
#        'GROUP BOOSTS SCANDINAVIA FUND <SCF> STAKE',
#        'ROYAL GOLD AND SILVER CORP <RGS.TO> SIX MTHS NET',
#        'BP SAYS NO PLANS TO CLOSE SWEDISH REFINERY',
#        'LTV <QLTV> GETS MARINE CORPS CONTRACT',
#        "DAYTON HUDSON <XXX> DOWNGRADED BY MOODY'S",
#        'SINO-U.S. VENTURE IN CHINA TO MAKE RINSING AGENTS',
#        'LONDON-U.S. TREASURY 30-YEAR BOND AT 95-18/32, UP NEARLY 5.0 POINTS -DEALERS\n',
#        'BOEING <BA> WINS NASA CONTRACT',
#        'BRITAIN, JAPAN CLASH OVER STOCK MARKET ACCESS',
#        'DISCRIMINATION CHARGES LIFTED AGAINST TWA <TWA>',
#        'U.S. TAX INCREASE PROPOSED ON BEER AND WINE',
#        'JAPAN CLARIFIES FUND MANAGEMENT REGULATIONS',
#        'DATRON SYSTEMS <DTSI> SEES LOWER YEAR NET',
#        'TX/W OKLA FEEDLOT CATTLE STDY/UP 0.50 DLR-USDA',
#        'BANKAMERICA <BAC> TO SELL GERMAN BANKING UNIT',
#        'KEVLIN MICROWAVE CORP <KVLM> 3RD QTR FEB 28 NET',
#        'FORD MOTOR <F> DISTRIBUTES PROFIT SHARING',
#        'GE <GE>, ALSTHOM <ALSF.PA> DEVELOPING TURBINE',
#        'U.S. OIL DEPENDENCY SEEN RISING TO RECORD LEVEL',
#        'ECUADOR QUAKE CAUSES 950 MLN DLRS IN LOSSES',
#        'DOLLAR ENDS LOWER IN LACKLUSTRE FRANKFURT',
#        'U.S. SENATE BILL SEEN HAMPERING FOREIGN BANKS',
#        'S. AFRICAN CONSUMER INFLATION FALLS IN SEPTEMBER',
#        'INTERSTATE (I) CHIEF DOUBTFUL ON BRAZIL DEBT',
#        'GATT OFFICIAL MEETS WITH U.S. FARM LEADERS',
#        "GOTABANKEN AND UNIT MAY BE DOWNGRADED BY MOODY'S",
#        'BFG PARTIAL OPERATING PROFITS FALL SHARPLY IN 1986',
#        'EC AGREES REDUCTION OF DIESEL EXHAUST EMISSIONS',
#        'ESCAGEN CORP <ESN> COMPLETES INITIAL OFFERING',
#        'ENDOTRONICS <ENDO> TARGET OF INVESTIGATION',
#        'DUTCH MONEY MARKET DEBT RISES IN WEEK',
#        'COOPER CANADA <CPC.TO> SETS SHARE CONSOLIDATION',
#        'THERMO PROCESS <TPSI> ACQUISITION TERMINATED',
#        'T.H.E. FITNESS <RFIT> BUYS LIVINGWELL UNIT',
#        'EC LEADERS BEGIN BRUSSELS SUMMIT',
#        'MARCADE GROUP <MAR> PLANS ACQUISITION',
#        'AMC <AMO> TO INSPECT 20,000 VEHICLES',
#        'CHRYSLER <C> MAY CAR OUTPUT FALLS',
#        'BANK OF NOVA SCOTIA RAISES U.S. DLR BASE RATE',
#        'CALNY <CLNY> GETS BID FROM PEPSICO <PEP>',
#        'BANK OF FRANCE AGAIN BUYING DOLLARS, SOURCES SAY',
#        'ECUADOR TO ASK OPEC TO RAISE EXPORT QUOTA',
#        ' Balladur maintains 1987 2.5 pct inflation target after February 3.4 pct year-on-year\n',
#        'ATT <T> TO REDEEM 15.5 MLN PREFERRED SHARES',
#        '<ENCOR ENERGY CORP INC> YEAR LOSS',
#        'TEXACO <TX> CONFIRMS TEXAS COURT FILING',
#        'NCNB <NCB> TO MERGE WITH (CENTRABANK)',
#        'ECUADOREAN UNIONS TO CALL GENERAL STRIKE',
#        'BELGIAN DECEMBER INDUSTRIAL OUTPUT FALLS',
#        'LONDON SDR DEPOSIT RATES - APRIL 7',
#        'HEINZ INTERESTED IN BUYING GUINNESS BREWING',
#        'EC WHEAT RELEASE UNLIKELY TO SATISFY U.K. DEMAND',
#        'JUSTICE ASKS U.S. DISMISSAL OF TWA (TWA) FILING',
#        'AMR <AMR> AIRCRAFT FINANCING SEEN POSITIVELY',
#        'NYSE CHAIRMAN SAYS MARKET DECLINE NOT A CRASH',
#        'RAYTHEON <RTN> DIRECTOR RESIGNS',
#        'MORGAN STANLEY SAYS IT ENTERED MARKET ON CLOSE ORDERS TOTALING 1.1 BILLION DLRS\n',
#        'CASH PORK CALLED MIXED, BEEF HIGHER',
#        'DOME PETROLEUM LTD YEAR OPER SHR LOSS 6.94 DLRS VS LOSS TWO CTS\n',
#        'JAPAN TO ALLOW MORE FOREIGN BROKERS AT AUCTIONS',
#        'CENTRAL BANCSHARES <CBSS> 1ST QTR NET',
#        "ECUADOR'S CONSUMER PRICES RISE 2.5 PCT IN FEBRUARY",
#        'CONSOLIDATED NATURAL GAS CO <CNG> IN PAYOUT',
#        'BRAZIL PLANS NEW ECONOMIC STRATEGY FOR GROWTH',
#        'SENATORS, PROSECUTOR DISAGREE ON IRAN TESTIMONY',
#        'FIRST INTERSTATE EXPECTS BRAZIL, ECUADOR LOAN ACTIONS TO CUT 1987 NET BY 15.4 MLN DLRS\n',
#        'GMK SAYS THREE KMA PARTNERS MULLING RECONSTRUCTION',
#        'CME SETS FEBRUARY TRADING VOLUME RECORD',
#        'AMERICUS TRUST FOR MERCK <MRK> NOW EFFECTIVE',
#        'FED SETS 2.5 BILLION DLR CUSTOMER REPURCHASE, FED SAYS\n',
#        'ECUADOR GETS LOAN TO HELP REPAIR OIL PIPELINE',
#        'CARDIS <CDS> EXPECTS SIGNIFICANT YEAR LOSS',
#        'OECD AGREES EXPORT CREDIT REFORMS',
#        'M.D.C. ASSET INVESTORS <MIR> IN INITIAL PAYOUT',
#        'MTECH <MTCH> FILES CONVERTIBLE DEBT OFFERING',
#        'GREAT AMERICAN <GTA> GAINS OVER 80 MLN IN LOANS',
#        'DAXOR <DAXR.O> IN FEDERAL EXPRESS <FDX> DEAL',
#        'USAIR GROUP IN DEFINITIVE AGREEMENT FOR TWO BILLION DLRS IN CREDIT\n',
#        'CADILLAC FAIRVIEW SAYS IT RECEIVED TAKEOVER BIDS',
#        'ADMAR GROUP <ADMR> OPENING NEW OFFICE',
#        'FRENCH MARKET TALK OF SYRIAN WHEAT PURCHASES',
#        'TOTAL ERICKSON <TLE.T> BUYS MINING PROPERTY',
#        '3M <MMM> ACQUIRES CONTROL DATA <CDA> UNIT',
#        'MET-COIL SYSTEMS CORP<METS> 3RD QTR FEB 28 NET',
#        'FED ADDS RESERVES VIA OVERNIGHT REPURCHASES',
#        'ROHM AND HAAS CO <ROH> 3RD QTR NET',
#        'AUSTRALIAN FOURTH QTR GDP RISES 1.1 PCT, AFTER 0.2 PCT THIRD QTR RISE - OFFICIAL.\n',
#        'KYOWA LICENSES AIDS TEST FROM MUREX',
#        'PRE-PAID LEGAL <PD> ENTERS WASHINGTON MARKET',
#        'TORONTO DOMINION BANK BUYS SEAT ON TORONTO STOCK EXCHANGE\n',
#        'WICKES <WIX> PLANS REVERSE SPLIT, CALLS DEBT',
#        'NATIONAL COMPUTER <NLCS.O> TO BUY SHARES',
#        'GLAXO <GLX> STOCK OFF ON ULCER REPORT',
#        'HANSON TRUST <HAN> COMPLETES KAISER PURCHASE',
#        'ECONOMIC SPOTLIGHT - TELECOM IS KEY JAPAN MINISTRY',
#        'MARGAUX CONTROLS INC <MARGX> 3RD QTR DEC 28 LOSS',
#        'ECUADOR OFFICIAL SEEKS OIL AID IN VENEZUELA',
#        'CHICAGO BOARD OF TRADE DELIVERABLE GRAIN STOCKS',
#        'AMERICAN CAN <AC> SEES HIGHER YEAR NET',
#        'SALOMON RAISES SIZE OF CMO TO 350 MLN DLRS',
#        'UNILEVER HAS IMPROVED MARGINS, VOLUMES IN 1986',
#        'OPPENHEIMER INDUSTRIES <OPP> SEES YEAR LOSS',
#        "USDA REJECTS SRI LANKA'S 80 U.S. DLR WHEAT PRICE",
#        'U.S. CREDITS FOR ECUADOR SWITCHED TO VEG OIL',
#        'LYNG DISAPPOINTED BY CANADA CORN INJURY DECISION',
#        'ENERGY/FOREIGN INVESTORS',
#        'AUSTRALIAN TREASURY NOTE TENDER 700 MLN DLRS',
#        'ANNUAL MAILING TO DELINQUENT FARMERS -- USDA',
#        'SYNTECH INTERNATIONAL <SYNE.O> SUES SOUTHLAND',
#        '(MONTREAL CITY, DISTRICT SAVINGS BANK) 1ST QTR',
#        'FIAT PLANS MORE INVOLVEMENT IN HIGH TECH SECTORS',
#        'CSR SELLING DELHI TO EXXON UNIT, DROPS DELHI FLOAT',
#        'U.S. CREDIT MARKETS END UNDER EXTREME PRESSURE',
#        'JAPAN VTR AND TV EXPORTS FALL IN FEBRUARY',
#        'U.S. COTTON CERTIFICATE EXPIRATION DATE EXTENDED',
#        'DONORS PLEDGE 3.15 BILLION DLRS INDONESIAN AID',
#        'U.S., CANADA SWITCH TO DAYLIGHT TIME SUNDAY',
#        'ECUADOR TO PRODUCE ABOVE OPEC QUOTA - MINISTER',
#        'AMERICAN MEDICAL <AMI> REPURCHASING COMMON',
#        'SEA CONTAINERS <SCR> EXPECTS BETTER FIRST QTR',
#        'REAGAN VOWS TO BLOCK TAX HIKE IN HIS PRESIDENCY',
#        ' Stoltenberg says he assumes monetary cooperation will continue\n',
#        'JURY FINDS FOR DOW <DOW> IN BIRTH DEFECT CASE',
#        'LONDON LIFFE S.FRANC CLOSE 1616 - APR 7',
#        'CHEMICAL <CHL> NET HURT BY BRAZIL, EXPENSES',
#        'SAUDI SUCCESS SEEN IN CURBING OPEC PRODUCTION',
#        'AUSTRALIA LEADING INDEX CONTINUES RISE IN DECEMBER',
#        'DUTCH SUGAR TRADE DENY INVOLVEMENT IN OFFER',
#        'LAWSON FORECASTS 2.5 BILLION STG U.K. CURRENT ACCOUNT DEFICIT IN 1987\n',
#        "CHINA'S FIFTH SECURITIES MARKET TO OPEN",
#        'CME SETS MAY 29 START FOR LUMBER FUTURES OPTIONS',
#        'DOW CHEMICAL CO <DOW> 3RD QTR NET',
#        'DEBT SOLUTION REQUIRES OPEN MARKETS, GERMAN BANKER',
#        'SIOUX CITY CATTLE SEEN UP 0.50-1.00 DLR-PRIVATE',
#        'HOECHST AG <HFAG.F> YEAR 1986',
#        'NISSAN <NSAN.T>, LANCER IN FORKLIFT AGREEMENT',
#        'PENTA SYSTEMS INTERNATIONAL INC <PSLI> 4TH QTR',
#        'MEDIQ <MED> IN AMERICAN MEDICAL <AMI> UNIT BUY',
#        'FREDDIE MAC ADJUSTS SHORT-TERM DISCOUNT RATES',
#        'ECONOMIC SPOTLIGHT - JAPAN PUSHES ITS CHIPMAKERS',
#        'U.S. CORN DEMAND GROWING IN JAPAN, SOUTH KOREA',
#        'BRAND COMPANIES <BRAN> SEES FIRST QUARTER LOSS',
#        'JAPANESE FIRMS TO SELL AUSTRALIAN GOLD COINS',
#        'WORLD BANK TEAMS STUDYING PHILIPPINE LOAN REQUESTS',
#        'U.K. BUILDING SOCIETY TAPS EUROSTERLING MARKET',
#        '<RANGE ROVER> TO SELL VEHICLES IN U.S.',
#        'DOE RUN RAISES LEAD PRICE 0.50 CT TO 26.50 CTS',
#        'GUNZE SANGYO ISSUING 25 MLN SWISS FRANC NOTES',
#        'PEPCO <POM> TWO MTHS FEB 28 NET',
#        'PREWAY INC <PREW> 4TH QTR LOSS',
#        'MANUFACTURERS HANOVER CORP <MHC> SETS DIVIDEND',
#        'LME LISTS BRAZILIAN ALUMINIUM BRAND',
#        'SYSTEMS FOR HEALTH CARE IN ONE-FOR-50 SPLIT',
#        'CYPRUS LOWERS COPPER PRICE 1.25 CTS TO 67 CTS',
#        'TULTEX <TTX> INCREASES DIVIDEND',
#        'EGYPT, SOVIET UNION TO RENEGOTIATE ARMS DEBT TERMS',
#        'LOTUS DEVELOPMENT CORP <LOTS.O> 3RD QTR NET',
#        'BEVERLY ENTERPRISES <BEV> DEBT LOWERED BY S/P',
#        'ECUADOR UNABLE TO SERVICE DEBT - CENTRAL BANK',
#        'HEALTHMATE INC SAYS AUDITORS INTEND TO QUALIFY ITS FINANCIAL STATEMENTS\n',
#        'CROWN RESOURCES <CRRS> PLANS ENERGY UNIT SALE',
#        'DATAMETRICS CORP <DMCZ> 1ST QTR JAN 31 NET',
#        'N.J. BUSINESS CONVERTS MAGAZINE TO MONTHLY',
#        'TESCO FORECASTS PROFITS RISE THIS YEAR',
#        'HAWKE POPULARITY RISES DESPITE ECONOMIC PROBLEMS',
#        'FRANCE WILL FIGHT EC FARM PROPOSALS - MINISTER',
#        'U.K. MONEY MARKET GIVEN FURTHER 68 MLN STG HELP',
#        'PANCONTINENTAL OIL HAS PRIVATE FINANCING',
#        'JEFFERIES GROUP CHAIRMAN RESIGNS, PLEADS GUILTY TO SECURITIES VIOLATIONS\n',
#        'ECOLAB <ECL> SEES RECORD FISCAL YEAR',
#        'EIA SAYS DISTILLATE STOCKS OFF 8.8 MLN, GASOLINE OFF 500,000, CRUDE OFF 1.2 MLN\n',
#        'CULP <CULP.O> SEES LOWER SECOND QUARTER',
#        'MALAYSIA RAISES DUTY ON PROCESSED PALM OIL',
#        'CCC ACCEPTS BONUS ON POULTRY TO EGYPT -- USDA',
#        'U.S. BUDGET CHIEF THREATENS VETO, PREDICTS DEAL',
#        'ENERGY VENTURES CINC <ENGY> 4TH QTR NET',
#        'FRANCE PLANS TO COVER SOCIAL SECURITY DEFICIT',
#        'DANSKE BANK IS FIRST DANISH BANK TO ISSUE CDS',
#        "GUARANTEE <GFCC> UNIT'S DEBT ON S/P WATCH",
#        'SCOTT PAPER <SPP> TO UPGRADE PULP FACILITIES',
#        'BALLY <BLY> CONSIDERING SALE OF SIX FLAGS',
#        'N.Z. FOREIGN DEBT FALLS TO 32.94 BILLION DLRS',
#        'NEXXUS <NEXX> SIGNS CONTRACTS WORTH 10 MLN DLRS',
#        'CRUDE OIL PRICES UP AS STOCKS, OUTPUT FALL',
#        'LEAR SIEGLER HOLDING CORP PLANS TO DIVEST AEROSPACE SUBSIDIARY\n',
#        'PANAMANIAN WHEAT SHIP STILL GROUNDED OFF SYRIA',
#        'PENNZOIL <PZL> PLOTS STRATEGY TO FIGHT TEXACO',
#        'SIGNET BANKING CORP REGULAR DIVIDEND',
#        'STORA CLOSE TO COMPLETING PAPYRUS TAKEOVER',
#        'SONY INCREASING PRODUCTION ABROAD',
#        'MONOCLONAL ANTIBODIES <MABS> ORDER BARS SALES',
#        'PUBLISHERS EQUIPMENT <PECN>, TRENTONIAN IN DEAL',
#        'EC TO ABOLISH TAX ON SPANISH MAIZE EXPORTS',
#        'DOLE SAYS REAGAN CHANGED NO MINDS ON VETO',
#        "JAPAN'S JOBLESS SEEN RISING TO 3.3 PCT IN 1987/88",
#        'U.S. SENATE, HOUSE BUDGET CHIEFS AGREE ON TAX',
#        'EASTMAN KODAK <EK> SELLS 25 MLN DLRS OF NOTES',
#        'WORLD BANK SEEKS MORE AGGRESSIVE DEBT ROLE',
#        'MIDWAY AIRLINES <MDWY> SETS HOLDER RIGHTS PLAN',
#        'ECUADOR NAMES NEW INDUSTRY AND TRADE MINISTER',
#        'JAPAN STUDY URGES FOREIGN ACCESS TO FARM MARKETS',
#        'VENEZUELA TO LEND OIL TO ECUADOR FOR EXPORT',
#        "FEDERAL PAPER BOARD <FBP> UPGRADED BY MOODY'S",
#        'REPUBLIC AUTOMOTIVE PARTS <RAUT> 4TH QTR LOSS',
#        'ECUADOR ADOPTS AUSTERITY PROGRAM',
#        'PARTNERSHIP BUYS IPCO <IHS> STAKE OF 6.8 PCT',
#        'U.S. CORN MARKET SKEWED BY SOVIET BUYING',
#        'PREMIER SAYS YUGOSLAVIA WILL PAY ITS DEBTS',
#        'MCLEAN INDUSTRIES <MII> UNIT TRANSERS SERVICE',
#        'GENERAL MOTORS <GM> TO IDLE 9,800 WORKERS',
#        'CREDIT CARD DISCLOSURE BILLS INTRODUCED',
#        'LAWSON SAYS G-7 TO REVIEW PARIS ACCORD NEXT WEEK',
#        'ALLTEL <AT> GETS PERMISSION FOR LICENSE TRANSFER',
#        'HOWARD BAKER AIDE EXPECTED TO GET TOP JOB',
#        'U.S. URGES BANKS TO DEVELOP NEW 3RD WLD FINANCE',
#        'EC COMMISSIONER WELCOMES COCOA ACCORD',
#        'U.S. RETAIL SALES ROSE 4.1 PCT IN FEB, NON-AUTO SALES ROSE 1.5 PCT\n',
#        'AMERICAN CYNAMID CO <ACY> SETS DIVIDEND',
#        'COLOMBIA BUYS 25,000 TONNES FRENCH WHEAT - TRADE',
#        'FRENCH AEROSPATIALE TO MAKE EURO-CP ISSUE',
#        'NYSE SAYS ADVEST <ADV> DECLINES COMMENT',
#        'comalco ltd 1986 net profit 57.1 mln dlrs vs loss 69.1 mln\n',
#        'VIOLENCE REPORTED IN ECUADOR GENERAL STRIKE',
#        'EC GRANTS 25,000 TONNES BARLEY, 80,000  FRENCH MAIZE LICENCES, REJECTS WHEAT - TRADERS\n',
#        'U.K. FEBRUARY ADJUSTED STERLING M3 RISES 2-1/4 PCT, M0 DOWN 3/4 TO ONE PCT - OFFICIAL\n',
#        'BUFFTON CORP <BUFF> BUYS B AND D INSTRUMENTS',
#        ' OECD SEES 1.5 PCT WEST GERMAN REAL GNP GROWTH IN 1987\n',
#        'HAYES-ALBION <HAY> COMPLETES GOING PRIVATE DEAL',
#        'DAVIS WATER <DWWS> RELEASES PRE-SPLIT EARNINGS',
#        "FED'S JOHNSON SAYS PRICE STABILITY CRITICAL FOR NON-INFLATIONARY EXPANSION\n",
#        'U.S. SELLING 12.8 BILLION DLRS OF 3 AND 6-MO BILLS MARCH 23 TO PAY DOWN 2.875 BILLION DLRS\n',
#        'OPEC MAY HAVE TO MEET TO FIRM PRICES - ANALYSTS',
#        'ECONOMIST SEES SLOWDOWN IN U.S. ECONOMIC GROWTH',
#        'ECUADOR SIGNS 280 MLN DLR IADB LOAN',
#        'SERVICE CORP INTERNATIONAL <SRV> SETS QUARTERLY',
#        'ENZO BIOCHEM <ENZO> CONTRACT PAYMENT WITHHELD',
#        'ANALOGIC CORP <ALOG> 2ND QTR JAN 31 NET',
#        'FISCHER-WATT TO SELL CONVERTIBLE PREFERRED',
#        'YUGOSLAV TRADE FALLS SHARPLY  STATISTICS SHOW',
#        'LONDON COFFEE CLOSES FIRMER IN DULL TRADING',
#        'FRASER AND NEAVE LTD <FRNM.SI> HALF YR TO MARCH 31',
#        'CHINA CLOSES SECOND ROUND OF OFFSHORE OIL BIDS',
#        'SWEDISH INDUSTRY SEES HIGHER 1987 PRODUCTION',
#        'USX <X> PROVED OIL, GAS RESERVES FALL IN 1986',
#        'NL INDUSTRIES <NL> STUDIES SPIN OFF',
#        'ECUADOR TO EXPORT NO OIL FOR FOUR MONTHS, OFFICIAL',
#        "MOODY'S RATES ADB'S SENIOR SAMURAI BONDS AAA",
#        'LOWER U.S. FARM PAYMENT BASE EYED FOR SAVINGS',
#        'U.S. REGULATORS TO CONSIDER CBT EVENING SESSION',
#        'ISLAMIC BANKS ESTABLISH 50 MLN DLR TRADE PORTFOLIO',
#        'KNUTSON MORTGAGE CORP <KNMC> SETS QUARTERLY',
#        'COFFEE, SUGAR AND COCOA EXCHANGE NAMES CHAIRMAN',
#        'NEW DUTCH SPECIAL ADVANCES ANNOUNCED AT 5.3 PCT',
#        'BROKERS SAY NYSE RULE SHIFT LIMITS FLEXIBILITY',
#        'AMERICAN EXPRESS BANK LTD WILL ADD 600 MLN DLRS TO LOAN\nLOSS RESERVES\n\n',
#        'SWEDISH DRUG FIRM ASTRA RISE ON AIDS HOPES',
#        'U.S. CREDIT MARKET OUTLOOK - SPENDING, M-1',
#        'K MART <KM> RAISES PAYOUT, VOTES SPLIT',
#        'ANGLO AMERICAN <AIVJ.J> YEAR TO DEC 31',
#        'VENEZUELA BACKS INCREASE IN ECUADOR OPEC QUOTA',
#        '<FRUIT OF THE LOOM INC> INITIAL OFFERING STARTS',
#        'JAPANESE BANKRUPTCIES DECLINE IN FEBRUARY',
#        'CHINA SIGNS WORLD BANK LOAN FOR TIANJIN PORT',
#        "PAKISTAN'S FOREIGN EXCHANGE RESERVES FALL",
#        'ECUADOR BEGINS WORK ON OIL PIPELINE TO COLOMBIA',
#        'GREEK BULK ORE CARRIER AGROUND IN ORINOCO RIVER',
#        "FED'S JOHNSON SAYS HE DOES NOT SEE INCREASING PRESSURE ON INTEREST RATES\n",
#        'NUMEREX CORP <NMRX> 2ND QTR JAN 31 LOSS',
#        'ELI LILLY <LLY> TO SELL ELIZABETH ARDEN UNIT',
#        'THACKERAY CORP <THK> YEAR LOSS', 'BTR PLC <BTRX.L> 1986 YEAR',
#        'VERSATILE TO BUILD POLAR ICE BREAKER',
#        'IEA SAYS OPEC FEBRUARY CRUDE OUTPUT 16.1 MLN BPD',
#        'GLENMEDE TRUST TO SELL PART OF SUN <SUN> STOCK',
#        'DE HAVILLAND, SHORT MAY MOVE ON PLANE THIS YEAR',
#        'Japan September M-2 plus CD money supply rises 11.1 pct year on year (Aug 11.0)\n',
#        'SIX REPORTED WOUNDED IN ECUADOR GENERAL STRIKE',
#        'BANGOR HYDRO-ELECTRIC CO <BANG> SETS DIVIDEND',
#        'GM <GM> MAY CAR OUTPUT FALLS 26.3 PCT',
#        'VIACOM <VIA> EXECUTIVE RESIGNS',
#        'CITIZENS FIRST BANCORP INC <CFB>RAISES DIVIDEND',
#        'HAGENSBORG RESOURCES <HGS.V> RAISES SEVEN MLN',
#        '<FRANKLIN NEW YORK TAX-FREE INCOME FUND> PAYOUT',
#        'N.Y. PLATINUM FUTURES FINISH HIGHER',
#        'AUSTRALIAN FOREIGN SHIP BAN ENDS',
#        'ECUADOR SEEKS HALT TO PAYMENTS TO BANKS IN 1987',
#        'SERVICE RESOURCES CORP <SRC> 4TH QTR NET',
#        'CURRENCY INSTABILITY WILL NOT LAST - SUMITA',
#        'U.S. COULD APPROVE EGYPTIAN M-1A TANK PRODUCTION',
#        'COASTAL CORP <CGP> AND UNITS UPGRADED BY S/P',
#        'AMERICAN MOTORS <AMO> LATE FEBRUARY SALES OFF',
#        'SWEDEN HAS CURRENT PAYMENTS SURPLUS IN 1986',
#        'COOPER BASIN NATURAL GAS RESERVES UPGRADED',
#        'U.S. LAWMAKERS SAY STOCK DIVE CALLS FOR SUMMIT',
#        'LEECO <LECO.O> EXPANDS SALES TEAM',
#        'WORLD BANK EXPECTED TO APPROVE PHILIPPINES LOAN',
#        'GINNIE MAE DROPS FEE INCREASE ON SECURITIES',
#        'UNIVERSAL RESOURCES <UVR>HOLDERS APPROVE MERGER',
#        'OLSON INDUSTRIES <OLSN> TO SELL EGG OPERATIONS',
#        'NOVELL <NOVL> SETS TWO FOR ONE STOCK SPLIT',
#        'GTE <GTE> UNIT SIGNS DEAL WITH SKYSWITCH',
#        'TREASURY BALANCES AT FED ROSE ON FEB 27',
#        'TENNECO <TGT> TO REDEEM 11 DLR PREFERRED',
#        'ECONOMIC SPOTLIGHT - IRISH BUDGET',
#        "HENLEY <HENG> TO ISSUE SUBSIDIARY'S SHARES",
#        'DUTCH COST OF LIVING FALLS 1.2 PCT IN FEBRUARY',
#        'ADVANCED SYSTEMS <ASY> TO DISTRIBUTE COURSES',
#        'SYNERGETICS <SYNG> GETS FLOOD CONTROL ORDER',
#        'ECUADOR TO USE COLOMBIA OIL LINK FOR FIVE YEARS',
#        'ECUADOR SAYS IT WILL PAY DEBT WHEN IT CAN',
#        'FED SETS TWO BILLION DLR CUSTOMER REPURCHASE, FED SAYS\n',
#        'SUZUKI RECALLS 63,000 CARS',
#        "LOWE'S COS <LOW> RAISES QUARTERLY ONE CT",
#        'NEW MONTREAL NEWSPAPER FOLDS',
#        'CONTROL RESOURCE INDUSTRIES INC <CRIX> 4TH QTR',
#        'MALAYSIA BAILS OUT ANOTHER COMMERCIAL BANK',
#        'VENEZUELA APPROVES WAGE INCREASES, PRICE CONTROLS',
#        'ALITALIA SPA <AZPI.MI> CALENDAR 1986',
#        'MINSTAR INC SAID IT SOLD ALL 10 MLN OF ITS BORG-WARNER SHARES\n',
#        ' Poehl says chances for exchange rate stability are good\n',
#        'JMB REALTY TRUST <JMBRS> 2ND QTR FEB 28 NET',
#        'DELTA AIR <DAL> FEBRUARY LOAD FACTOR FALLS',
#        'BELL ATLANTIC <BEL> UNIT HAS MARKETING APPROVAL',
#        'SOVIET SPRING CROPS SOWN ON ONLY 11 PCT OF LAND',
#        'MINAS DE ALMADEN RAISES MERCURY PRICE',
#        'SSMC <SSM> TO BUY CUTTERS EXCHANGE DIVISION',
#        '<CCL INDUSTRIES INC> 4TH QTR NET',
#        "L'AIR LIQUIDE <AIRP.PA> YEAR ENDED DEC 31",
#        'NATIONAL SEMI <NSM>, CANON IN DEVELOPMENT PACT',
#        'LEAR PETROLEUM <LPT> CONSOLIDATES GAS UNITS',
#        'PROXMIRE SAYS FSLIC CONFERENCE SET FOR NEXT WEEK',
#        'SOSNOFF ENDS DEAL WITH PRATT, SOUTHMARK ON POSSIBLE\nVENTURE FOR CAESARS BID    \n',
#        'MORTON THIOKOL <MTI> GETS 61.4 MLN DLR CONTRACT',
#        'WISCONSIN POWER AND LIGHT CO <WPL>VOTES PAYOUT',
#        'CREDITOR BANKS MAY BUY INTO SINGAPORE COFFEE FIRM',
#        'PAYLESS CASHWAYS <PCI> SEES BETTER FIRST QTR',
#        'NOVO INDUSTRI A/S (NVO.CO) YEAR 1986',
#        'CHINESE BANKS TO ISSUE MORE BONDS, OFFICIAL SAYS',
#        'GUYANA FINANCE MINISTER OPTIMISTIC BUT SEEKS HELP',
#        'UNITED TELECOM <UT> UNIT NAMES NEW PRESIDENT',
#        'NYMEX SCHEDULES START OF HEATING OIL OPTIONS',
#        'ANITEC IMAGE <ANTC> FILES FOR DEBT OFFERING',
#        'PRESIDENT NAMED FOR DISNEY <DIS> EUROPEAN PARK',
#        'RAYROCK TO ISSUE 24 MLN DLRS OF NOTES',
#        'AUSTRALIAN FOREIGN SHIP BAN ENDS BUT NSW PORTS HIT',
#        'PACIFIC STOCK EXCHANGE SHORT INTEREST UP',
#        'U.S. SENATOR TO PROPOSE 0/92 FOR 1987 CROPS',
#        'NYSE TO HOLD NEWS CONFERENCE AFTER CLOSE',
#        "JAPAN TO SCRUTINISE LIFE INSURERS' CAPITAL GAINS",
#        'SUZUKI MOTOR PLANS HUNGARIAN JOINT CAR VENTURE',
#        'U.S. REAL GNP ROSE 1.1 PCT IN FOURTH QUARTER',
#        'STATOIL SEEKS SHARE IN THAI GAS FIELD',
#        'LEUCADIA <LUK> HAS 7.2 PCT OF MINSTAR <MNST>',
#        'BRAZIL CROP WEATHER SUMMARY -- USDA/NOAA',
#        'GRUMMAN CORP <GQ> IN PAYOUT',
#        'FIRST MISSISSIPPI CORP <FRM> SETS QUARTERLY',
#        'GENERAL MOTORS (GM) CANADA TO CLOSE TRUCK CENTRE',
#        'ECUADOR ECONOMY SEEN CONTRACTING IN 1987',
#        'VALERO ENERGY KNOWS OF NO REASON FOR STOCK GAIN',
#        'HELABA UNIT ISSUES LUXEMBOURG FRANC PLACEMENT',
#        'BRAZIL COMPUTER MARKET TO REMAIN CLOSED-MINISTER',
#        'ICCO BUYS 5,000 TONNES COCOA FOR BUFFER STOCK',
#        '<FINANCIAL TRUSTCO CAPITAL LTD> HIKES PAYOUT',
#        'PENNSYLVANIA ENTERPRISES <PENT.O> BID STANDS',
#        "MOODY'S DOWNGRADES DAYTON HUDSON'S 1.3 BILLION DLRS OF DEBT\n",
#        'ANALYST SAYS DART GROUP LIKELY BIDDER FOR SUPERMARKETS GENERAL\n',
#        'GATT STAFF STRIKE OVER PAY AND PENSION LOSSES',
#        'MCDONNELL <MD> SAID TALKS AT INFORMAL STAGE',
#        'EC COMMISSION HAS OPEN ATTITUDE ON STEEL QUOTAS',
#        'RUGBY WELL PREPARED FOR NEW CEMENT COMPETITION',
#        'GULF ESCORTS STILL UNDER DISCUSSION - WEINBERGER',
#        'INVESTCORP SIGNS FOR 75 MLN DLR CREDIT FACILITY',
#        'MERIDIAN <KITS> LICENSES PARASITE TEST KIT',
#        'SOVIET TRADE DEFICIT WITH WEST SOARS IN 1986',
#        'DUCOMMON INC <DCO> 4TH QTR LOSS',
#        'FORMER GOLD FIRM EXECUTIVES ARRESTED IN JAPAN',
#        'GROUP SAYS U.S. HOSTAGE ILL, OFFERS SWAP',
#        'ANGLO CHIEF URGES S.AFRICA REPEAL DISCRIMINATION',
#        'BURMESE PADDY PRODUCTION LOWER IN 1986/87',
#        'U.S. NON-FARM PRODUCTIVITY FELL 2.2 PCT IN QTR',
#        'GULL <GLL> IN PRIVATE SALE OF NOTES',
#        'SAUDIS DROP CONDITION FOR OIL SALE TO BRAZIL',
#        "TREASURY'S BAKER PURSUING S. ASIAN REVALUATIONS",
#        'KAUFMAN SAYS GREENSPAN NOMINATION BAD FOR BONDS',
#        'FTSE 100 share index opens 136.9 points down at 2,165 - London Stock Exchange\n',
#        'P.C. QUOTE INC <PCQT> YEAR LOSS',
#        "TREASURY'S MULFORD SEES BRAZIL LENDING PROGRESS",
#        'VENEZUELA TO LEND UP TO 12.5 MLN BARRELS OF OIL',
#        'BARRIS IND. SAYS IT LEADS GROUP WITH 9.8 PCT OF MEDIA GENERAL, MAY SEEK CONTROL\n',
#        'ARBED SA <ARBB.BR> YEAR 1986',
#        'NIGERIAN CURRENCY FIRMS AT LATEST AUCTION',
#        'UNICORP CANADA<UNI.A> CUTS PUROLATOR<PCC> STAKE',
#        'DOM REPUBLIC SELLS CZARNIKOW 35,000 TONS SUGAR',
#        'HADSON <HADS> TO OFFER FOUR MLN SHARES',
#        'BOLIVIAN DEBT BUYBACK PLAN GAINS GROUND',
#        'U.K. INTERVENTION BOARD DETAILS EC SUGAR SALES',
#        'TEMPO ENTERPRISES INC <TPO> YEAR NET',
#        "TRADE ISSUES STRAINING EC'S PATIENCE WITH JAPAN",
#        'GAF <GAF> SEEN RAISING BORG-WARNER <BOR> BID',
#        'MALAYSIA EXPECTS RUBBER SHORTAGE IN APRIL/MAY',
#        'CCR VIDEO <CCCR> NOW MEETS NASDAQ REQUIREMENTS',
#        'STOKELY USA INC <STKY> REGULAR DIVIDEND SET',
#        'LIVE HOG FUTURES HIGHER EARLY',
#        'UK MINISTER SAYS FARM TALKS CAN USE OECD STUDY',
#        'ICE UNCHANGED AT SOVIET OIL PORT OF VENTSPILS',
#        'U.K. GRAIN EXPORTS CONTINUE TO RISE SHARPLY',
#        'ISLAMIC BANK MAKES 12.3 MLN DLRS OF LOANS',
#        'ENEX RESOURCES CORP <ENEX> 4TH QTR LOSS',
#        'JACOBS ENGINEERING <JEC> TO REINCORPORATE',
#        'PHILIPPINES, WORLD BANK SIGN 310 MLN DLR PACKAGE',
#        'BIOSEARCH MEDICAL PRODUCTS INC <BPMI> 4TH QTR',
#        'MAFINA ISSUES 200 MLN SFR BOND WITH WARRANTS',
#        'GREYCOAT GROUP SEEKS TWO FINANCINGS',
#        'GM <GM> CANADA UNIT MAJOR OFFER ACCEPTED BY UNION',
#        'NASD PRESIDENT LEAVES FOR HAMBRECHT AND QUIST',
#        'PIEDMONT AVIATION INC <PIE> SETS QUARTERLY',
#        'YEUTTER SAYS U.S.-JAPAN TRADE DIFFICULTIES REMAIN',
#        'JAPANESE MINISTRY DENIES EXPORT QUOTA FOR DAIHATSU',
#        'SOUTHLAND <SLC> MAY BE DOWNGRADED BY S/P',
#        'POLL SHOWS AMERICANS HOLD ON TO STOCKS AFTER DROP',
#        'CHRYSLER <C> CANADA MARCH CAR SALES UP 9.7 PCT',
#        'BASF U.S. PROFIT,TURNOVER BOOSTED BY ACQUISITIONS',
#        'ALTUS BANK <ALTS.O> FAILS TO REACH AGREEMENT',
#        'SETON <SEL> DIRECTORS APPROVE MERGER AGREEMENT',
#        'PACIFIC STOCK EXCHANGE CLOSING FIGURES DELAYED',
#        'ASIAN COCOA PRODUCERS EXPAND DESPITE CRITICS',
#        "GANNETT'S <GCI> USA TODAY'S ADVERTISING RISES",
#        'JARDINE MATHESON HOLDINGS LTD <JARD.HKG> YEAR 1986',
#        'H.K. STOCK EXCHANGE MULLS NEW RULE FOR "B" SHARES',
#        'WESTERN CO OF NORTH AMERICA <WSN> 3RD QTR LOSS',
#        'CPC INTERNATIONAL INC <CPC> REGULAR DIVIDEND',
#        'REAGAN READY TO IMPOSE TRADE CURBS AGAINST JAPAN',
#        'MEPC EXTENDS OFFER FOR OLDHAM',
#        'JAPAN TO RELEASE GNP FIGURES LATER TODAY',
#        'GREAT WESTERN <GWF> OFFERS 2.5 MLN COMMON SHARES',
#        'U.K. MONEY RATES FIRM ON LAWSON STERLING TARGETS',
#        'VANGUARD TECHNOLOGIES <VTI> WINS CONTRACT',
#        'TAIWAN HOLDING TALKS WITH ADB, TAIWAN OFFICIAL',
#        'WAREHOUSE CLUB <WCLB.O> MAY LOWER RESERVES',
#        'PHELPS DODGE <PD> SEES STRONGER COPPER PRICES',
#        'HEALTHSOUTH <HSRC.O> MAKES ACQUISITION',
#        'DIGITAL AUDIO TAPE PLAYERS GO ON SALE IN JAPAN',
#        'BRITAIN CALLS FOR FIGHT AGAINST PROTECTIONISM',
#        'DOSKOCIL <DOSK> SHAREHOLDERS VOTE REVERSE SPLIT',
#        'MIAMI-Brazil and bank advisory committee agree to 60-day extension on credit lines\n',
#        'YUGOSLAV 1990 STEEL OUTPUT TO HIT 6.3 MLN TONNES',
#        ' Top discount rate at U.K. Bill tender falls to 9.3657 pct\n',
#        '<SAPC INC> SUES LOTUS <LOTS> OVER COPYRIGHT',
#        'KUWAIT SAID SEEKING FOREIGN PROTECTION FOR OIL',
#        'HONG KONG FEBRUARY TRADE SWINGS INTO DEFICIT',
#        'LANGE PREDICTS N.Z. INFLATION TO FALL TO 8-10 PCT',
#        'LONDON GRAINS SEE FURTHER NEARBY WHEAT GAINS',
#        'JAPAN ADOPTS STOP-GAP BUDGET',
#        'ECUADOR SEEKS HALT TO PAYMENTS TO BANKS IN 1987',
#        "COEUR D'ALENE MINES CORP <COUR> 4TH QTR LOSS",
#        'HENLEY GROUP REVIEWING INVESTMENT IN SANTA FE SOUTHERN PACIFIC\n',
#        'ALLIED <ASU> SELLING MICHIGAN UNITS',
#        'CANADIAN IMPERIAL BANK LOWERING VISA RATES',
#        'SOUTHLAND <SLC> UNIT RAISES CRUDE POSTINGS',
#        'ST LOUIS HOGS SEEN STEADY/UP 0.50 DLR - PRIVATE',
#        'YUGOSLAV WORKERS MAY BE ANGERED BY LOST SUBSIDIES',
#        'COMBUSTION ENGINEERING <CSP> IN PUBLIC OFFERING',
#        'TURKEY SEEN UNLIKELY TO JOIN EC THIS CENTURY',
#        '<CONSOLIDATED PIPE LINES CO> YEAR NET',
#        'HALLMARK STORES SELLS SECURED BONDS',
#        'AEG TO REORGANIZE ENERGY BUSINESS',
#        'NATNED FORECASTS 1987 RESULTS IN LINE WITH 1986',
#        'ECUADOR SAYS IT WILL PAY DEBT WHEN IT CAN',
#        'ECUADOR ADOPTS AUSTERITY MEASURES AFTER QUAKE',
#        'ECUADOR HAS TRADE SURPLUS IN FIRST FOUR MONTHS',
#        'AUSTRALIAN BUSINESS URGED TO RESTRAIN PROFITS',
#        'HOLIDAY <HIA> SEES RULING NEXT WEEK ON PLAN',
#        'R.J.R. NABISCO UNIT FORMS OVERSEEING COMMITTEE',
#        'BURLINGTON NORTHERN INC 1ST QTR SHR PROFIT 93 CTS VS LOSS 3.55 DLRS\n',
#        'MARSH AND MCLENNAN COS INC <MMC> SETS QUARTERLY',
#        'GTE <GTE> SELLS DEBENTURES YIELDING 8.737 PCT',
#        'SHOWBOAT <SBO> TO TAKE CHARGE, SEES 3RD QTR LOSS',
#        'MOUNTAIN STATES <MTSR> ADDES TWO PROPERTIES',
#        'SPHINX MINING <SPNXF.O> FINDS GOLD',
#        'Sumita says world stockmarkets excessively concerned about economic future\n',
#        'MITSUBISHI CHEMICAL INDUSTRIES LTD <MCIT.T> YEAR',
#        'JAPAN AUCTIONS 1,000 BILLION YEN SHORT-TERM PAPER',
#        'U.S. MARCH JOBLESS RATE FELL TO 6.6 PCT',
#        'NIGERIA REVERSES POLICY, RESTORES MINIMUM WAGE',
#        "FED'S HELLER URGES JAPANESE TO BUY U.S. GOODS",
#        'TRIBUNE CO TO ISSUE UP TO 100 MLN DLRS IN MEDIUM TERM\nNOTES\n',
#        'OPEC FUND APPROVES 100,000 DLR AID FOR ECUADOR',
#        'MAZDA DOES NOT PLAN TO MAKE SPORTS CARS IN U.S.',
#        'USDA DENIES CHANGES IN TEXAS GULF DIFFERENTIALS',
#        'TALKING POINT/VIACOM INTERNATIONAL <VIA>',
#        'OCEAN BIO-CHEM INC <OBCI> YEAR NET',
#        'SIOUX FALLS HOGS UP 1.50/1.75 DLR - USDA',
#        'ALC <ALCC> ANTICIPATES 1ST QTR PROFIT',
#        'TERMIFLEX CORP <TFLX.O> 1ST QTR SEPT 30 NET',
#        'CCR VIDEO SAYST RECEIVED OFFER TO NEGOTIATE A TAKEOVER BY INTERCEP INVESTMENT CORP\n',
#        'FRENCH MATIF SUSPENDS QUOTATIONS FOR ONE HOUR UNTIL 1000 GMT -- OFFICIAL\n',
#        'CONCERN OVER "EL NINO" IN PERU - USDA REPORT',
#        'NATIONAL HEALTHCARE <NHCI.O> CHAIRMAN RESIGNS',
#        'BANK OF JAPAN INTERVENES TO STEM DOLLAR FALL',
#        'APPLIED SOLAR ENERGY CORP <SOLR> 1ST QTR NET',
#        'SEASONAL STABILISATION SEEN FOR COFFEE PRICES',
#        'FEBRUARY U.S. RETAIL SALES NOT SIGN OF UPTURN',
#        'BEMIS CO <BMS> 3RD QTR NET',
#        'BRENDA MINES SELLING KERR ADDISON SHARES',
#        'ECUADOR SUSPENDS PAYMENTS TO PRIVATE BANKS',
#        'FIRST BOSTON INC 3RD QTR SHR 1.15 DLRS VS 76 CTS\n',
#        'TALKING POINT/EASTERN AIRLINES <TEX>',
#        'U.S. AID CHIEF TO BE NAMED TO TOP TREASURY POST',
#        'GENENTECH <GENE> SETBACK VIEWED AS TEMPORARY',
#        'NIPPON LIFE, SHEARSON TIE-UP SEEN SETTING TREND',
#        'LONDON GOLD 1500 FIX - JUNE 2 - 455.00 DLRS\n',
#        'ST PAUL HOGS OPEN UP 0.50 DLR - PRIVATE SOURCES',
#        'TAIWAN INDUSTRIAL OUTPUT RISES SHARPLY IN MARCH',
#        'SALICK HEALTH CARE INC <SHCI.O> 2ND QTR NET',
#        'GLAXO PROFITS UP SHARPLY, DIVIDEND RAISED',
#        'HUTCHISON UNIT BUYS CONTAINER CRANES FROM JAPAN',
#        'GENERAL MILLS <GIS> REALIGNS EDDIE BAUER',
#        'OCCIDENTAL <OXY> HAS STAKE IN NORWAY OIL FIND',
#        'BERLINER BANK ISSUES 50 MLN AUSTRALIAN DLR BOND',
#        'SANDVIK, DIAMANT BOART FINALISE DRILLS MERGER',
#        'CANADA GDP UP 0.1 PCT IN JANUARY',
#        '<TECHNIMED CORP> HAS CHOLESTEROL TEST PRODUCT',
#        'CANADA ALLOWS PUBLISHING TAKEOVER BY HARCOURT',
#        'GERMAN VEBA PLACEMENT SAID LIKELY EARLY NEXT WEEK',
#        'ARDEN GROUP <ARDNA.O> PLANS ISSUER TENDER',
#        'GEODYNAMICS CORP <GDYN> 3RD QTR FEB 27 NET',
#        'REAGAN CALLS FOR W. GERMAN, JAPANESE GROWTH',
#        'SCRAP CREPE RUBBER PRICES FIRAT COLOMBO AUCTION',
#        'DUTCH GREEN COFFEE IMPORTS FALL IN JANUARY',
#        'LVI GROUP <LVI> TO MAKE ACQUISITION',
#        'U.S. FARM CREDIT BANKS DEFER APRIL 20 OFFERING',
#        'LAWSON WANTS STERLING AROUND 1.60 DLRS, 2.90 MKS',
#        'DIVI HOTELS <DVH> WARRANT PRICE ADJUSTED',
#        'S. AFRICAN PRODUCER PRICE INFLATION FALLS SHARPLY',
#        'ROCKEFELLER CENTER PROPERTIES <RCP> UPS PAYOUT',
#        "ECUADOR'S CEPE NAMES NEW HEAD",
#        'RANGER <RGO> SETS TERMS OF EUROBOND OFFER',
#        'DOW <DOW> SEES RECORD ANNUAL PROFITS IN 1987',
#        'FAA ADMINISTRATOR ENGEN TO RESIGN IN JULY',
#        'KLEINWORT BENSON AUSTRALIAN FUND <KBA> DIVIDEND',
#        'JAPAN MINISTRY SAYS OPEN FARM TRADE WOULD HIT U.S.',
#        'RSI CORP <RSIC> 2ND QTR FEB 28 NET',
#        'INDIA EXPORTS ITS FIRST PASSENGER CARS',
#        'IMF APPROVES 48 MLN DLR LOAN TO ASSIST ECUADOR',
#        'ECUADOR QUAKE TO CUT OIL REVENUES 800 MLN DLRS',
#        'TOLL BROTHERS INC <TOL> 1ST QTR JAN 31 NET',
#        'MURRAY OHIO <MUR> SEES HIGHER FIRST QUARTER NET',
#        'DREXEL TELLS U.S. STOCK BUYERS TO LOOK ABROAD',
#        'IBM <IBM>, BELL ATLANTIC <BEL> IN STUDY PACT',
#        "WHITE HOUSE RAPS DEMOCRATS' BUDGET",
#        'GE <GE> SIGNS CONTRACT ON SMALL POWER PLANT',
#        'GATT STAFF STRIKE OVER PAY AND PENSION LOSSES',
#        'BANK OF JAPAN INTERVENES IN TOKYO',
#        'NETHERLANDS GRANTS 47 MLN DLRS TO BANGLADESH',
#        'UGANDA DISAPPOINTED BY COFFEE TALKS FAILURE',
#        'BRITAIN, U.S. TO DISCUSS JAPAN TRADE RELATIONS',
#        'IMPERIAL <ICA> DECLARES FIRST DIV SINCE 1981',
#        'MIDWEST GRAIN FUTURES 11:31   EDT',
#        'SINGAPORE PETROLEUM CO RAISES OIL PRODUCT POSTINGS',
#        'KEVEX CORP <KEVX> 2ND QTR JAN 31 NET',
#        'OPPENHEIMER RAISES NWA <NWA> EARNINGS ESTIMATE',
#        'ECUADOR TO EXPORT NO OIL FOR 4 MONTHS, OFFICIAL',
#        'SUPER VALU STORES INC <SVU> SETS REG DIV',
#        'FISHER SHAREHOLDER INDECISIVE OVER STOCK BUY',
#        'DALTON COMMUNICATIONS INC <DALT> 3RD QTR JAN 31',
#        'ECUADOR NEGOTIATES WITH NIGERIA FOR LENDING OIL',
#        'SPENDTHRIFT <SFI> REMOVED FROM AMEX',
#        'CHRONAR <CRNR> GETS CONTRACT',
#        'U.S. EXPORTERS REPORT 150,000 TONNES CORN  SOLD TO UNKNOWN DESTINATIONS FOR 1986/87\n',
#        'MOSCOW CARRIES OUT NUCLEAR TEST',
#        'ECUADOR DEPUTY MINISTER SEEKS OIL AID IN VENEZUELA',
#        'TEXACO (QTX) MAY BENEFIT FROM SEC BRIEF',
#        'NEW EEP DURUM WHEAT OFFER TO ALGERIA -- USDA',
#        'PENNEY <JCP> SETS STOCK SPLIT, RAISES QUARTERLY',
#        'ECONOMIC SPOTLIGHT - ASIAN DROUGHTS',
#        'BARCLAYS, MIDLAND FOLLOW NATWEST BASE RATE CUT',
#        'U.K. MONEY MARKET GIVEN 215 MLN STG LATE HELP',
#        'CLABIR <CLG> DIVIDENDS NOT TAXABLE',
#        'COUNTY SAVINGS BANK <CSBA> SETS STOCK DIVIDEND',
#        'USDA ESTIMATES 1986/87 USSR GRAIN IMPORTS  26.0 MLN TONNES VS 23.0 IN FEB, 29.9 IN 1985/86\n',
#        'CAREMARK <CMRK> CHANGES FISCAL YEAR-END',
#        'FISONS RAISING 110 MLN STG IN SHARE PLACING',
#        'NICHOLS RESEARCH CORP <NRES> 2ND QTR FEB 28',
#        'REAGAN EXTENDS U.S. COOPERATION WITH EURATOM',
#        'H.F. AHMANSON AND CO <AHM> 3RD QTR NET',
#        'BRAZIL COCOA EXPORTERS UNLIKELY TO LIMIT SALES',
#        'FAIRCHILD INDUSTRIES TERMINATES T46A TRAINER PROGRAM, CLOSES PLANT\n',
#        'PARADYNE <PDN> LAUNCHES MODEMS, NETWORK SYSTEM',
#        'S. KOREAN WHOLESALE PRICES UP 0.4 PCT IN MAY',
#        'LE PEEP RESTAURANTS SUES OHIO COMPANY',
#        'SOROS GROUP TELLS SEC IT MAY BUY UP TO 49.9 PCT OF FAIRCHILD INDUSTRIES\n',
#        'WEINBERGER OPPOSES FUJITSU BUYING U.S. FIRM',
#        'BANK OF NEW ENGLAND CORP <BKNE> QTLY DIVIDEND',
#        'WESTLB RAISES AUSTRALIAN DLR BOND TO 75 MLN',
#        'BOLIDEN SAYS RESULTS BURDENED BY LOSS WRITEOFF',
#        'TREASURY OFFICIAL SAYS PHILIPPINE PACT VERY NEAR',
#        'CANADIAN BANKER SAYS BRAZIL ECONOMIC GROWTH VITAL',
#        'AMERICAN EXPRESS <AXP> UNIT IN FUNDING PROGRAM',
#        'NEWELL CO <NWL> 3RD QTR NET',
#        'LILLY INDUSTRIAL COATINGS INC <LICIA> 1ST QTR',
#        'JAPAN SETS ASIDE YEN FUNDS TO PREVENT DLR FALL',
#        'NCR CORP 1ST QTR SHR 65 CTS VS 51 CTS\n',
#        "LONDON'S FTSE 100 SHARE INDEX DROPS RECORD 301.5 POINTS TO 2000.4 at 1457 GMT\n",
#        "BANCA D'AMERICA E D'ITALIA 1986 YEAR",
#        'CONQUEST EXPLORATION <CQX> WARRANTS EXPIRE',
#        'GREEN MOUNTAIN <GMP> TO SELL POWER TO UTILITY',
#        'SKANSKA TO TAKE STAKE IN CANADIAN FIRM',
#        'AMRO BANK PLANS 300 MLN GUILDER 6.75 PCT BONDS',
#        'NEW CURRENCY PROBLEM SEEN AMONG U.S, EUROPE, JAPAN',
#        'AEGON EXPECTS MODERATE RISE IN 1987 PROFITS',
#        'U.S. APPEARS TO TOLERATE FURTHER DLR DECLINE',
#        '<WILDERNESS EXPERIENCE INC> 4TH QTR LOSS',
#        'ISRAEL IN NINTH AIR RAID OVER LEBANON THIS YEAR',
#        'HOG AND CATTLE SLAUGHTER GUESSTIMATES',
#        'PRIME COMPUTER <PRM> TO BUY BACK STOCK',
#        'CBOE TO LIST NEW S AND P OPTIONS APRIL 20',
#        'STERIVET <STVTF> TO DEVELOP NEW HORSE DRUG',
#        'LIFETIME CORP <LFT> YEAR MARCH 27 NET',
#        'U.S. EXPORTERS REPORT 350,000 TONNES CORN  SOLD TO UNKNOWN DESTINATIONS FOR 1986/87\n',
#        'JAPAN SEEN CUTTING APRIL BOND COUPON FROM FIVE PCT',
#        'SYRIA PROPOSES REDUCED BUDGET FOR 1987',
#        'ECHLIN INC <ECH> DIVIDEND INCREASED 12 PCT',
#        'MCKESSON <MCK> SELLS CULINARY ACADEMY',
#        'U.S. SENATE LEADER WANTS BUDGET PASSED THIS WEEK',
#        'UNION CAMP <UCC> TO BUY BACK SHARES',
#        'TURKISH CENTRAL BANK SETS LIRA/DOLLAR, DM RATES',
#        'VIOLENCE REPORTED IN ECUADOR GENERAL STRIKE',
#        'MERRILL <MRLL> BUYS FRAYN FINANCIAL PRINTING',
#        'S. KOREA ORDERS MERGERS OF TROUBLED COMPANIES',
#        'AMERICAN PRE-PAID IN PACT WITH TWO DISTRIBUTORS',
#        'KROGER <KR> SAYS UNION REJECTS CONTRACT',
#        'DENMARK IN 600 MLN CROWN EUROBOND DEAL',
#        'BAY STATE GAS <BGC> PREFERRED UPGRADED BY S/P',
#        'BANK OF ZAMBIA PAYS OUT FOREIGN CURRENCY ARREARS',
#        'BORG-WARNER AGREES TO BUYOUT BY MERRILL LYNCH FIRM',
#        'MOORE FINANCIAL GROUP <MFGI.O> QUARTERLY DIV',
#        'United Biscuits pretax profit 125.2 mln stg vs 102.2 mln in 53 wks to Jan 3\n',
#        'PEPS BOYS-MANNY, MOE AND JACK <PBY> SET PAYOUT',
#        'BANK OF SPAIN GOVERNOR SAYS MONEY GROWTH TOO FAST',
#        'SUBROTO SAYS EXTENSION OF TIN PACT IS UNREALISTIC',
#        'SHULTZ SAYS U.S. WHEAT BONUS OFFER UP TO USDA',
#        'BELL ATLANTIC CORP <BEL> 3RD QTR NET',
#        'SRI LANKA TO LAUNCH APPEAL FOR DROUGHT AID',
#        '(CORRECTED) - GOODYEAR <GT> TO SELL CELERON',
#        'CITIZENS FIRST BANCORP INC <CFB> DIVIDEND SET',
#        'NEW ENGLAND SAVINGS BANK <NESB> 1ST QTR NET',
#        'COMMERCIAL INTERNATIONAL <CMMC> MAKES PURCHASE',
#        'BRAZIL COTTON CROP LOWER -- USDA REPORT',
#        'CHINA LIGHT UNIT RENEWS COMMERCIAL PAPER FACILITY',
#        'ECUADOR ACCEPTS EXPLORATION BIDS',
#        'USDA ADJUSTS LOUISIANA GULF PRICE DIFFERENTIALS',
#        'SENATOR SAYS ENERGY REPORT ASSUMPTIONS FLAWED',
#        'FIRST VALLEY CORP <FIVC.O> 3RD QTR NET',
#        'C. ITOH SEES NO GROWTH IN 1987/88 GROUP PROFIT',
#        'MORGAN STANLEY <MS> ISSUES MORTGAGE BONDS',
#        'JAPAN STUDY URGES FOREIGN ACCESS TO FARM MARKETS',
#        'PORLA CRUDE PALM OIL TRADE REPORT FOR APRIL 2',
#        'LSI LOGIC CANADA FILES FOR OFFERING',
#        'PRIMARK CORP <PMK> REGULAR DIVIDEND',
#        'PRESIDENT REAGAN URGES PASSAGE OF BALANCED BUDGET AMENDMENT\n',
#        'NAKASONE DEFENDS SALES TAX AS CAMPAIGNING BEGINS',
#        'U.S. BUSINESS LOANS FELL 822 MLN DLRS IN MARCH 25 WEEK, FED SAYS\n',
#        'SOME 7,000 SOUTH AFRICAN MINERS RETURN TO WORK',
#        'YIELD ON 91-DAY SAMA DEPOSITS RISES',
#        'COOPERVISION HAS 6.5 PCT OF COOPER LASER <ZAPS>',
#        'RECENT U.S. OIL DEMAND UP 0.1 PCT FROM YEAR AGO',
#        'GROWTH OF PALM OIL USE SET TO SLOW, OUTPUT TO RISE',
#        'CONAGRA INC <CAG> 3RD QTR FEB 22 NET',
#        'FRENCH OFFICIAL RESERVES 420.50 BILLION FRANCS IN MAY VS\n420.24 BILLION APRIL - OFFICIAL\n',
#        'PACAD INC <BAGS> IN PACT WITH OKAMOTO U.S.A.',
#        'UNITED TECHNOLOGIES GETS 502.1 MLN DLR CONTRACT',
#        'LATIN COFFEE MEETING TO BE HELD IN MANAGUA',
#        '<AUSTIN ROVER GROUP> REPORTS SALES ON STERLINGS',
#        'CITICORP <CCI> DENIES RUMORS OF DEBT WRITEDOWN',
#        'SWISS BANKER SAYS COUNTRIES SEEK NEW DEBT ANSWERS',
#        'PERLE QUITS AS PENTAGON ARMS CONTROL EXPERT',
#        'LITTLE JOY FOR SWISS EXPORTERS, STUDY SAYS',
#        'U.S. PAYMENTS GAP TO PERSIST, EX-FED CHIEF SAYS',
#        'NEW PROCESS CO <NOZ> SETS QTLY PAYOUT',
#        'PARKER DRILLING <PKD> SUSPENDS PAYOUT',
#        'GM <GM> DEALERS ORDER 125,000 NEW CHEVROLETS',
#        'QMS INC <AQM> 4TH QTR OCT 2 NET',
#        'BOWNE AND CO <BNE> TO REPURCHASE ONE MLN SHARES',
#        'NATIONAL INTERGROUP<NII> TO OFFER PERMIAN UNITS',
#        'INDUSTRIAL ACTION ENDS AT SOUTH AFRICAN MINE',
#        'DAYTON HUDSON <DH> NOT INTERESTED IN ACQUISITION',
#        'RAINIER REALTY <RRETS.O> NOTE INTEREST RAISED',
#        'LONDON INTERNATIONAL RAISE PROFITS BY 3.05 MLN',
#        'DIAGNOSTIC PRODUCTS <DPCZ> SEES EARNINGS GROWTH',
#        'EQUITABLE LIFE ASSURANCE NAMES UNIT CHIEF',
#        'QUEBEC FEBRUARY HOUSING STARTS FALL',
#        'J.P. MORGAN SAYS BRAZIL ACTION WILL REDUCE FIRST QUARTER\nNET BY ABOUT 20 MLN DLRS\n',
#        'ST SYSTEMS <STX> WINS NASA CONTRACT',
#        'TOYOTA SAYS IT ONLY STUDYING LUXURY UNIT PLANS',
#        'JARDINE MATHESON PLANS FOUR-FOR-ONE BONUS ISSUE',
#        'CHRYSLER <C> PAYS 77 MLN DLRS IN BONUSES',
#        'NYSE ASKS MEMBERS TO REFRAIN FROM USING ORDER SYSTEM FOR PROGRAM TRADING\n',
#        'CPC EXPECTS EUROPEAN SALE TO CUT DEBT',
#        'LOBLAW COS TO SELL 75 MLN DLRS OF DEBENTURES',
#        'SEC TO PROBE TWO CONVICTED OF SECURITIES FRAUD',
#        'WARNER <WCI> HAS 8.2 PCT BERKEY INC <BKY> STAKE',
#        'STOLTENBERG SAYS PARIS ACCORD POLICY TO CONTINUE',
#        'COLOMBIA JAN EXPORTS UP BUT COFFEE VALUES FALL',
#        'GEICO CORP <GEC> NAMES NEW BOARD MEMBERS',
#        "CHASE'S LABRECQUE SAYS STOCK DROP UNWARRANTED",
#        'ROYALE AIRLINES <RYAL> REPORTS LOAD FACTOR UP',
#        'U.S. BUSINESS LOANS FALL 618 MLN DLRS IN FEB 25 WEEK, FED SAYS\n',
#        'TOP QUALITIES SOUGHT ON HAMBURG COFFEE MARKET',
#        'COMEX SILVER FUTURES CLOSE ON HIGHS',
#        'NYSE TO DISCLOSE IMBALANCES TWICE TOMORROW',
#        'U.S. BANKS TO GET APPROVAL FOR SECURITIES BUSINESS',
#        'WORLD MARKET PRICE FOR UPLAND COTTON - USDA',
#        'ABIDJAN PORT ACTIVITY RISES',
#        'P AND O PLANS WARRANT ISSUE TO MARK ANNIVERSARY',
#        'JAPAN FUND <JPN> SEEKERS CONFIDENT OF FINANCING',
#        'MORTGAGE AND REALTY <MRT> ELECTS NEW PRESIDENT',
#        'NATIONAL SAVINGS MOVE POINTS TO LOWER U.K. RATES',
#        'ECUADOR CRUDE OIL OUTPUT TO RESUME NEXT MONTH',
#        'FRENCH GDP SHOULD RISE 2.3 PCT IN 1988 - MINISTRY'], dtype='<U91')

# %%
with_titles = reuters.with_column(
    'Title', reuters.apply(get_title, "Raw text")
)
with_titles
# Out:
# Raw text                                                     | Title
# <reuters cgisplit="PUBLISHED-TESTSET" lewissplit="NOT-US ... | LYNG SETS TOUGH U.S. STANCE WITH JAPAN ON BEEF
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ... | DE LAURENTIIS COMPANIES SEE LOSS ON FILM
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | PORTUGUESE TRADE DEFICIT NARROWS IN 1986
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | BIOGEN <BGNF> GETS PATENT FROM EUROPEAN OFFICE
# <reuters cgisplit="PUBLISHED-TESTSET" lewissplit="NOT-US ... | DEFENSE CONTRACTOR BOOSTS BIRD <BIRD> STAKE
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | MOODY'S MAY DOWNGRADE RESORTS INTERNATIONAL <RT>
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | RECORD N.Z. FUTURES VOLUMES TRADED IN FEBRUARY
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | SWISS SIGHT DEPOSITS RISE 743.7 MLN FRANCS
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | IRAN SAYS IT INTENDS NO THREAT TO GULF SHIPPING
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | BUSINESSLAND <BUSL> COMPLETES OFFERING
# ... (990 rows omitted)

# %%
_ = tests.grade('q2_3')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# Now we'll go through a similar process to get the date of each article.  In each article, the date is on its own line, separated from the rest of the article by `<date>` and `</date>` markers.  You can check one of the articles for an example.
#
# **Question 4.** Write a function called `get_date`.  It should take as its argument the whole text of an article and return the date.  The date should be just the day of the year (so January 1 is day 1, and February 1 is day 32, since January has 31 days).  Note that all the articles are from the year 1987, so the year is irrelevant.
#
# We've written a function called `date_string_to_day` that will help you do this.

# %%
# This function is provided for you to use.  Read at least
# its documentation (the stuff at the beginning in red).
def date_string_to_day(date_string):
    """Converts a string that looks like a date into the day of the year.
    
    Parameters
    ----------
    date_string : str
        Text that contains a date in any reasonable format.
        For example, "September 13, 1994" or "9/13/94" or
        "13-SEP-1994 15:02:20.00" all work.
    
    Returns
    -------
    int
        The day of the year that the date represents.
    
    Examples
    --------
    >>> date_string_to_day("January 3, 2016")
    3
    
    >>> date_string_to_day("February 4, 2000")
    35
    """
    from dateutil import parser
    import re
    # Some of the Reuters dates have extraneous text at the end.
    # This removes that text.
    date_part = re.sub(" [A-Z]*$", "", date_string)
    try:
        date = parser.parse(date_part)
    except:
        print("Failed on", date_string)
    day_in_year = date.timetuple().tm_yday
    return day_in_year

# Fill in this function.
def get_date(article_text):
    date_text = get_text_in_markers(article_text, "date")
    day_in_year = date_string_to_day(date_text)
    return day_in_year
    

# When you're done, this should produce 92.
get_date(reuters.column("Raw text").item(0))
# Out:
# 92

# %%
_ = tests.grade('q2_4')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# **Question 5.** Use your function to find the date of every article in `with_titles`. Create a new table called `with_dates` that's a copy of `with_titles` with an extra column named "Date" that contains the dates.

# %%
with_dates = with_titles.with_column(
    "Date", with_titles.apply(get_date, "Raw text")
)
with_dates
# Out:
# C:\Users\Rwang\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1206: UnknownTimezoneWarning: tzname F identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\Rwang\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1206: UnknownTimezoneWarning: tzname RM identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\Rwang\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1206: UnknownTimezoneWarning: tzname G identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\Rwang\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1206: UnknownTimezoneWarning: tzname V identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\Rwang\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1206: UnknownTimezoneWarning: tzname C identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# Raw text                                                     | Title                                            | Date
# <reuters cgisplit="PUBLISHED-TESTSET" lewissplit="NOT-US ... | LYNG SETS TOUGH U.S. STANCE WITH JAPAN ON BEEF   | 92
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ... | DE LAURENTIIS COMPANIES SEE LOSS ON FILM         | 170
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | PORTUGUESE TRADE DEFICIT NARROWS IN 1986         | 70
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | BIOGEN <BGNF> GETS PATENT FROM EUROPEAN OFFICE   | 85
# <reuters cgisplit="PUBLISHED-TESTSET" lewissplit="NOT-US ... | DEFENSE CONTRACTOR BOOSTS BIRD <BIRD> STAKE      | 92
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | MOODY'S MAY DOWNGRADE RESORTS INTERNATIONAL <RT> | 68
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | RECORD N.Z. FUTURES VOLUMES TRADED IN FEBRUARY   | 61
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | SWISS SIGHT DEPOSITS RISE 743.7 MLN FRANCS       | 82
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | IRAN SAYS IT INTENDS NO THREAT TO GULF SHIPPING  | 81
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | BUSINESSLAND <BUSL> COMPLETES OFFERING           | 70
# ... (990 rows omitted)

# %%
_ = tests.grade('q2_5')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# **Question 6.** There was a series of earthquakes in Ecuador on March 6, 1987.  Most Reuters news stories about Ecuador from that period were related to the earthquake or its political and economic consequences.  Find out when Reuters reported on the earthquake by making a histogram of all the dates of the articles whose *titles* include the word `"ECUADOR"`.  Use bins of width 3.
#
# *Hint:* The function `are.containing` creates a predicate that matches strings that contain a given string.  You can find its documentation by running `are.containing?`.

# %%
# Use these bins:
bins = np.arange(0, 375, 3)

with_dates.where('Raw text' ,are.containing("Ecuador")).hist("Date", bins=bins)
with_dates.where('Raw text' ,are.containing("Ecuador"))
# Out:
# Raw text                                                     | Title                                             | Date
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | ECUADOR CRUDE OIL EXPORTS STOPPED FOR FIVE MONTHS | 70
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | VENEZUELA-ECUADOR OIL LOAN UNDER DISCUSSION       | 76
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | PARIBAS SEEKING TO ADJUST ECUADOR OIL FACILITY    | 75
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ... | ECUADOR SAYS WILL RESUME LIMITED OIL PRODUCTION   | 103
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ... | BALTEK <BTEK.O> BUYS ECUADORIAN PLANT             | 292
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | IMF, DEVELOPMENT BANKS, TO ASSIST ECUADOR         | 71
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | ECUADOR DEBT TO BE HONOURED AFTER QUAKE SURVIVAL  | 70
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | ECUADOR TO ASK OPEC TO RAISE EXPORT QUOTA         | 71
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | VENEZUELA TO LEND ECUADOR 50,000 BPD OF CRUDE     | 71
# <reuters cgisplit="TRAINING-SET" lewissplit="TRAIN" newi ... | EARLY MARCH OPEC OUTPUT SEEN WELL BELOW CEILING   | 64
# ... (43 rows omitted)

# %% [markdown]
# **Question 7.** Make another histogram of the same data, but this time using different bins.  The first bin should start at day 0, and each bin should have a width of 10 days. Then, **using only your own inspection of the histogram (and no other Python code)**, estimate the proportion of Ecuador articles that were reported between days 50 and 100 of the year (including day 50 but not day 100). (The proportion should be out of the total number of articles whose titles include "ECUADOR".) Give that number the name `proportion_50_to_100`.

# %%
# Make a histogram as described above.  (Be sure to use the
# bins described in the question.)
...

# By inspecting your histogram, estimate the proportion of
# Ecuador articles that were reported between days 50 and 100
# of the year.  (It's hard to get exactly the right answer
# from a histogram like this, so it's okay if your answer is
# off by a little bit.)

bins = np.arange(0, 375, 10)
with_dates.where('Raw text' ,are.containing("Ecuador")).hist("Date", bins=bins, unit="days")
with_dates.where('Raw text' ,are.containing("Ecuador"))


proportion_50_to_100 = .8

# %% [markdown]
# **Question 8.** Your histogram should show several long gaps in coverage about Ecuador during the year.  By exploring the dataset, try to explain this.  Use the code cell below for your explorations.

# %%
with_dates.where("Date", are.between(130,320)).where("Raw text", are.containing('Ecuador'))
# Out:
# Raw text                                                     | Title                                          | Date
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ... | BALTEK <BTEK.O> BUYS ECUADORIAN PLANT          | 292
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ... | ECUADOR POSTS 71.3 MLN DLR 8-MTH TRADE DEFICIT | 293
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ... | ECUADOR TO PRODUCE ABOVE OPEC QUOTA - MINISTER | 180
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ... | VENEZUELA BACKS INCREASE IN ECUADOR OPEC QUOTA | 292
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ... | ECUADOR HAS TRADE SURPLUS IN FIRST FOUR MONTHS | 169
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ... | ECUADOR'S CEPE NAMES NEW HEAD                  | 293
# <reuters cgisplit="TRAINING-SET" lewissplit="TEST" newid ... | IMF APPROVES 48 MLN DLR LOAN TO ASSIST ECUADOR | 180
# <reuters cgisplit="PUBLISHED-TESTSET" lewissplit="NOT-US ... | ECUADOR ACCEPTS EXPLORATION BIDS               | 166

# %% [markdown]
# The articles written later in the year involve assistance, recovery, purchases of ecuador plants, or otherwise aftereffects of the earthquake.

# %% [markdown]
# ## 3. Causes of Death in California

# %% [markdown]
# This exercise is designed to give you practice using the Table method `group`.
#
# We'll be looking at a dataset from the California Department of Public Health (available [here](http://www.healthdata.gov/dataset/leading-causes-death-zip-code-1999-2013) and described [here](http://www.cdph.ca.gov/data/statistics/Pages/DeathProfilesbyZIPCode.aspx)) that records the cause of death (as recorded on a death certificate) for everyone who died in California from 1999 to 2013.  The data are in the file `causes_of_death.csv.zip`.  Each row records the number of deaths by one cause in one year in one ZIP code.
#
# To make the file smaller, we've compressed it; run the next cell to unzip and load it.

# %%
#!unzip -o causes_of_death.csv.zip

# %%
causes = Table.read_table('causes_of_death.csv')

causes
# Out:
# Year | ZIP Code | Cause of Death | Count | Location
# 1999 | 90002    | SUI            | 1     | (33.94969, -118.246213)
# 1999 | 90005    | HOM            | 1     | (34.058508, -118.301197)
# 1999 | 90006    | ALZ            | 1     | (34.049323, -118.291687)
# 1999 | 90007    | ALZ            | 1     | (34.029442, -118.287095)
# 1999 | 90009    | DIA            | 1     | (33.9452, -118.3832)
# 1999 | 90009    | LIV            | 1     | (33.9452, -118.3832)
# 1999 | 90009    | OTH            | 1     | (33.9452, -118.3832)
# 1999 | 90010    | STK            | 1     | (34.060633, -118.302664)
# 1999 | 90010    | CLD            | 1     | (34.060633, -118.302664)
# 1999 | 90010    | DIA            | 1     | (34.060633, -118.302664)
# ... (320142 rows omitted)

# %%
causes.group('Year')
# Out:
# Year | count
# 1999 | 21210
# 2000 | 21266
# 2001 | 21322
# 2002 | 21518
# 2003 | 21406
# 2004 | 21210
# 2005 | 21406
# 2006 | 21406
# 2007 | 21448
# 2008 | 21518
# ... (5 rows omitted)

# %% [markdown]
# The causes of death in the data are abbreviated.  If you want to know what the abbreviations mean, we've provided a table called `abbreviations.csv`.

# %% [markdown]
# **Question 1.** Find the top 5 causes of death in California over the entire period covered by the data.  To do that, create a table with one row for each of the top 5 causes of death, a column called "Cause of Death", and a column called "Count" that records the total number of deaths due to that cause.  Sort it in descending order by count, and call it `top_5_causes`.

# %%
# Use this cell to find the top 5 causes of death. cahnged to years because somthing wrong with counting causes, causes the same number. I think its some sort of overflow. 
#top_5_causes=causes.group("Cause of Death").sort("count",descending=True).take([0,1,2,3,4])
#top_5_causes

# Use this cell to find the top 5 years of death.
top_5_years=causes.group("Year").sort("count",descending=True).take([0,1,2,3,4])
top_5_years
# Out:
# Year | count
# 2008 | 21518
# 2002 | 21518
# 2007 | 21448
# 2013 | 21420
# 2006 | 21406

# %%
years=causes.group("Year").sort("count",descending=True)
years
# Out:
# Year | count
# 2008 | 21518
# 2002 | 21518
# 2007 | 21448
# 2013 | 21420
# 2006 | 21406
# 2005 | 21406
# 2003 | 21406
# 2012 | 21392
# 2001 | 21322
# 2000 | 21266
# ... (5 rows omitted)

# %%
_ = tests.grade('q3_1')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
#  > Suite 1 > Case 1
#
# >>> top_5_causes
# Cause of Death | count
# SUI            | 22868
# STK            | 22868
# PNF            | 22868
# OTH            | 22868
# NEP            | 22868
#
# # Error: expected
# #     Cause of Death | Count
# #     HTD            | 957108
# #     CAN            | 822906
# #     OTH            | 637764
# #     STK            | 231897
# #     CLD            | 194961
# # but got
# #     Cause of Death | count
# #     SUI            | 22868
# #     STK            | 22868
# #     PNF            | 22868
# #     OTH            | 22868
# #     NEP            | 22868
#
# Run only this test case with "python3 ok -q q3_1 --suite 1 --case 1"
# ---------------------------------------------------------------------
# Test summary
#     Passed: 0
#     Failed: 1
# [k..........] 0.0% passed

# %%
def calc(count):
    return count/years.column("count").sum()

with_proportion=years.with_column(
"proportion", years.apply(calc,"count")
)
top_5_proportion = with_proportion.take([0,1,2,3,4])
top_5_proportion
#check should sum to 1
#with_proportion.column("proportion").sum()
# Out:
# Year | count | proportion
# 2008 | 21518 | 0.0672118
# 2002 | 21518 | 0.0672118
# 2007 | 21448 | 0.0669932
# 2013 | 21420 | 0.0669057
# 2006 | 21406 | 0.066862

# %% [markdown]
# **Question 2.** Create a bar chart that displays the *proportion of all deaths* by each cause.

# %%
with_proportion.barh("Year", "proportion")

# %% [markdown]
# **Question 3.** Create a plot of the total number of deaths per year in California.
#
# *Hint:* Use the Table method `plot`.  The first argument is the name or index of the column to put on the horizontal axis.

# %%
# This line will make the vertical axis start at 0.  You can remove
# it if you want to see the default plot, which is more zoomed-in.
plt.ylim(0, 300000)

years.plot("Year")

# %% [markdown]
# **Question 4.** You should see that deaths have increased a little over time, though not uniformly.  How would you explain that?  Describe a dataset you'd like to see to test whether your explanation is valid.

# %% [markdown]
# Deaths peaked in 2002 and 2008, post economic crash. Can Check a dataset of suicides specifically to see if it matches the 2008 spike.

# %%
# For your convenience, you can run this cell to run all the tests at once!
import os
print("Running all tests...")
_ = [tests.grade(q[:-3]) for q in os.listdir("tests") if q.startswith('q')]
print("Finished running all tests.")
